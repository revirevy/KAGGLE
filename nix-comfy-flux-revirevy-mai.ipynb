# %%
# !ps fax| grep -i -E 'comfy|main'
# Out:
#      74 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#      76 pts/0    S+     0:00      \_ grep -i -E comfy|main

# %%
# %pwd
# Out:
# '/kaggle/working'

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/revirevy/nix_comfy_kaggle.git"
REPO_DIR = "/kaggle/working/nix_comfy_kaggle"

# Export GIT_DISCOVERY_ACROSS_FILESYSTEM
os.environ["GIT_DISCOVERY_ACROSS_FILESYSTEM"] = "1"

def run_command(cmd, cwd=None):
    """Run command with real-time output streaming"""
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        cwd=cwd
    )
    
    # Stream output while process runs
    for stream in [process.stdout, process.stderr]:
        if stream:
            for line in iter(stream.readline, ''):
                sys.stdout.write(line)
                sys.stdout.flush()
    
    return process.wait()

# Check if directory exists
if os.path.isdir(REPO_DIR):
    print(f"Directory '{REPO_DIR}' exists")
    
    if os.path.isdir(os.path.join(REPO_DIR, ".git")):
        print("Pulling latest changes...")
        retcode = run_command(["git",'-C',REPO_DIR, "pull", "--all"], cwd=REPO_DIR)
        if retcode != 0:
            print(f"Git pull failed with code {retcode}", file=sys.stderr)
    else:
        print("Not a Git repository - recloning...")
        subprocess.run(["rm", "-rf", REPO_DIR], check=True)
        print("Cloning repository...")
        retcode = run_command(["git", "clone", REPO_URL, REPO_DIR])
else:
    print("Cloning repository...")
    retcode = run_command(["git", "clone", REPO_URL, REPO_DIR])

# List contents
print(f"\nContents of '{REPO_DIR}':")
run_command(["ls", "-ltrha", REPO_DIR])
# Out:
# Directory '/kaggle/working/nix_comfy_kaggle' exists
# Pulling latest changes...
# Fetching origin
# Already up to date.
#
# Contents of '/kaggle/working/nix_comfy_kaggle':
# total 68K
# -rw-r--r-- 1 root root   57 Jun  2 11:32 README.md
# drwxr-xr-x 2 root root 4.0K Jun  2 11:32 __pycache__
# -rw-r--r-- 1 root root  29K Jun  2 11:32 main.py
# -rw-r--r-- 1 root root  12K Jun  2 11:32 LICENSE
# -rw-r--r-- 1 root root 3.4K Jun  2 11:32 .gitignore
# drwxr-xr-x 4 root root 4.0K Jun  2 11:32 .
# drwxr-xr-x 6 root root 4.0K Jun  2 11:32 ..
# drwxr-xr-x 7 root root 4.0K Jun  2 11:38 .git
# 0

# %%
import os, sys
os.chdir("/kaggle/working/nix_comfy_kaggle")
from main import *
main()
# Out:
# ============================================================
# Starting main function...
# ------------------------------------------------------------
# ============================================================
# Installing uv...
# ------------------------------------------------------------
# ============================================================
# Starting to link models...
# ------------------------------------------------------------
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/clip-gmp-vit-l-14/tensorflow2/default/1/model.safetensors' to '/kaggle/working/ComfyUI/models/clip/CLIP_gmp_VIT_L_14.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/t5xxl_fp16.safetensors/tensorflow2/default/1/t5xxl_fp16.safetensors' to '/kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux-vae-safetensors/pytorch/default/1/ae.safetensors' to '/kaggle/working/ComfyUI/models/vae/FLuX_ae.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/florence2/transformers/default/1/Florence2_model_3/model.safetensors' to '/kaggle/working/ComfyUI/models/LLM/Florence_model_3.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/florence2/transformers/default/1/Florence2_model_2/model.safetensors' to '/kaggle/working/ComfyUI/models/LLM/Florence_model_2.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux1devnf46stepsnsfw/pytorch/default/1/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/8stepscrearthyperfluxdevbnb_v24hyperdevfp8unet_/pytorch/default/1/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors' to '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/creart-hyper-flux-dev-gguf-q4_0/gguf/default/1/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf' to '/kaggle/working/ComfyUI/models/unet/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/unet/gguf/flux1-dev-q4_k_s/1/flux1-dev-Q4_K_S.gguf' to '/kaggle/working/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/albedobaseXL_v3Mini.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/alimama-flux-turbo-lora/pytorch/default/1/diffusion_pytorch_model.safetensors' to '/kaggle/working/ComfyUI/models/loras/alimama-flux-turbo-lora.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/fluxArtfusion4Steps_v12.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin' to '/kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/controlnet_instantid_model.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/instantid/LeInstantID_ControlNet_model.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xnomosunidat_upscaler.safetensors' to '/kaggle/working/ComfyUI/models/upscale_models/4xnomosunidat_upscaler.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flashface/pytorch/default/1/flashface.ckpt' to '/kaggle/working/ComfyUI/models/flashface/flashface.ckpt'
# ============================================================
# Models linked successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to link additional models...
# ============================================================
# RealESRGAN_x4plus.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/RealESRGAN_x4plus.pth' to '/kaggle/working/ComfyUI/models/upscale_models/RealESRGAN_x4plus.pth'
# 1xDeJPG_OmniSR.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/1xDeJPG_OmniSR.pth' to '/kaggle/working/ComfyUI/models/upscale_models/1xDeJPG_OmniSR.pth'
# 1xRedImage10000.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/1xRedImage10000.pth' to '/kaggle/working/ComfyUI/models/upscale_models/1xRedImage10000.pth'
# DPED.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/DPED.pth' to '/kaggle/working/ComfyUI/models/upscale_models/DPED.pth'
# BSRGANx2.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/BSRGANx2.pth' to '/kaggle/working/ComfyUI/models/upscale_models/BSRGANx2.pth'
# 4xLSDIRplusC.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplusC.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplusC.pth'
# 4xNomosUniDAT_otf.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomosUniDAT_otf.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomosUniDAT_otf.pth'
# RealESRGAN_x2plus.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/RealESRGAN_x2plus.pth' to '/kaggle/working/ComfyUI/models/upscale_models/RealESRGAN_x2plus.pth'
# 4xNomos8kSC.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomos8kSC.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomos8kSC.pth'
# 4xLSDIR.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIR.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIR.pth'
# DF2K.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/DF2K.pth' to '/kaggle/working/ComfyUI/models/upscale_models/DF2K.pth'
# 4x_NickelbackFS_72000_G.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4x_NickelbackFS_72000_G.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4x_NickelbackFS_72000_G.pth'
# 4xLSDIRplus.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplus.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplus.pth'
# 4xNomosWebPhoto_esrgan.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomosWebPhoto_esrgan.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomosWebPhoto_esrgan.pth'
# 4xLSDIRplusR.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplusR.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplusR.pth'
# 4x_RealisticRescaler_100000_G.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4x_RealisticRescaler_100000_G.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4x_RealisticRescaler_100000_G.pth'
# 4xNomos2_otf_esrgan.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomos2_otf_esrgan.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomos2_otf_esrgan.pth'
# 4xLSDIRplusN.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplusN.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplusN.pth'
# t5-v1_1-xxl-encoder-Q8_0.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf' to '/kaggle/working/ComfyUI/models/clip/t5-v1_1-xxl-encoder-Q8_0.gguf'
# t5-v1_1-xxl-encoder-f16.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-f16.gguf' to '/kaggle/working/ComfyUI/models/clip/t5-v1_1-xxl-encoder-f16.gguf'
# ip-adapter-plus_sdxl_vit-h.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-plus_sdxl_vit-h.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-plus_sdxl_vit-h.safetensors'
# controlnet-sd-xl-1.0-softedge-dexined.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-sd-xl-1.0-softedge-dexined.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-sd-xl-1.0-softedge-dexined.safetensors'
# ip-adapter-faceid-plusv2_sdxl.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-faceid-plusv2_sdxl.bin' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-faceid-plusv2_sdxl.bin'
# controlnet-v1e-sdxl-depth.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-v1e-sdxl-depth.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-v1e-sdxl-depth.safetensors'
# depth-zoe-xl-v1.0-controlnet.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/depth-zoe-xl-v1.0-controlnet.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/depth-zoe-xl-v1.0-controlnet.safetensors'
# CONTROLNET_INSTANTID_model.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/CONTROLNET_INSTANTID_model.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/CONTROLNET_INSTANTID_model.safetensors'
# OpenPoseXL2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/OpenPoseXL2.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/OpenPoseXL2.safetensors'
# ip-adapter_sdxl_vit-h.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter_sdxl_vit-h.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter_sdxl_vit-h.safetensors'
# ip-adapter.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter.bin' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter.bin'
# ip-adapter-plus-face_sdxl_vit-h.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-plus-face_sdxl_vit-h.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-plus-face_sdxl_vit-h.safetensors'
# controlnet-canny-sdxl-1.0_model_V2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-canny-sdxl-1.0_model_V2.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-canny-sdxl-1.0_model_V2.safetensors'
# diffusion_pytorch_model_twins.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/diffusion_pytorch_model_twins.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/diffusion_pytorch_model_twins.safetensors'
# ip-adapter-faceid_sdxl.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-faceid_sdxl.bin' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-faceid_sdxl.bin'
# ip-adapter_sdxl.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter_sdxl.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter_sdxl.safetensors'
# controlnet-union-sdxl-1.0_base_model.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-union-sdxl-1.0_base_model.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-union-sdxl-1.0_base_model.safetensors'
# controlnet-sd-xl-1.0-depth-16bit-zoe.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-sd-xl-1.0-depth-16bit-zoe.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-sd-xl-1.0-depth-16bit-zoe.safetensors'
# contronet-union-sdxl_model_promax.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/contronet-union-sdxl_model_promax.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/contronet-union-sdxl_model_promax.safetensors'
# [link_additional_models] Source directory does not exist: /kaggle/input/pulid-model/pytorch/default/4/
# INSTANTID_ip-adapter.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix_instantid_ipadapter/pytorch/default/1/INSTANTID_ip-adapter.bin' to '/kaggle/working/ComfyUI/models/controlnet/INSTANTID_ip-adapter.bin'
# INSTANTID_ip-adapter.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix_instantid_ipadapter/pytorch/default/1/INSTANTID_ip-adapter.bin' to '/kaggle/working/ComfyUI/models/instantid/INSTANTID_ip-adapter.bin'
# FLUX_ Upscaler_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_ Upscaler_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_ Upscaler_Jasperai.safetensors'
# FLUX_Depth_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Depth_Jasperai.safetensors'
# FLUX_Union_Pro_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Union_Pro_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Union_Pro_Shakkerai.safetensors'
# FLUX_Canny_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Canny_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Canny_Shakkerai.safetensors'
# FLUX_Depth_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Depth_Shakkerai.safetensors'
# flux-hed-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-hed-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/flux-hed-controlnet-v3.safetensors'
# flux-depth-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-depth-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/flux-depth-controlnet-v3.safetensors'
# flux-canny-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-canny-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/flux-canny-controlnet-v3.safetensors'
# FLUX_Surface_Normal_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Surface_Normal_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Surface_Normal_Jasperai.safetensors'
# SDXL-Openpose.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/SDXL-Openpose.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/SDXL-Openpose.safetensors'
# FLUX_ Upscaler_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_ Upscaler_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_ Upscaler_Jasperai.safetensors'
# FLUX_Depth_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Depth_Jasperai.safetensors'
# FLUX_Union_Pro_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Union_Pro_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Union_Pro_Shakkerai.safetensors'
# FLUX_Canny_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Canny_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Canny_Shakkerai.safetensors'
# FLUX_Depth_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Depth_Shakkerai.safetensors'
# flux-hed-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-hed-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/flux-hed-controlnet-v3.safetensors'
# flux-depth-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-depth-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/flux-depth-controlnet-v3.safetensors'
# flux-canny-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-canny-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/flux-canny-controlnet-v3.safetensors'
# FLUX_Surface_Normal_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Surface_Normal_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Surface_Normal_Jasperai.safetensors'
# SDXL-Openpose.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/SDXL-Openpose.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/SDXL-Openpose.safetensors'
# dmd2_sdxl_4step_unet_fp16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_4step_unet_fp16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/dmd2_sdxl_4step_unet_fp16.safetensors'
# dmd2_sdxl_1step_unet_fp16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_1step_unet_fp16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/dmd2_sdxl_1step_unet_fp16.safetensors'
# dmd2_sdxl_4step_lora_fp16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_4step_lora_fp16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/dmd2_sdxl_4step_lora_fp16.safetensors'
# Juggernaut-XI-byRunDiffusion-Lightning.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/juggernaut/pytorch/default/1/Juggernaut-XI-byRunDiffusion-Lightning.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/Juggernaut-XI-byRunDiffusion-Lightning.safetensors'
# Juggernaut-XI-byRunDiffusion.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/juggernaut/pytorch/default/1/Juggernaut-XI-byRunDiffusion.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/Juggernaut-XI-byRunDiffusion.safetensors'
# JuggernautXRundiffusion_Hyper.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/juggernaut/pytorch/default/1/JuggernautXRundiffusion_Hyper.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/JuggernautXRundiffusion_Hyper.safetensors'
# Epicrealismxl_Hades.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/Epicrealismxl_Hades.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/Epicrealismxl_Hades.safetensors'
# SG161222_RealVisXL_V5_0_Lightning.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/SG161222_RealVisXL_V5_0_Lightning.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/SG161222_RealVisXL_V5_0_Lightning.safetensors'
# hephaistosNextgen_v10ExperimentalBF16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/hephaistosNextgen_v10ExperimentalBF16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/hephaistosNextgen_v10ExperimentalBF16.safetensors'
# sdxlLightning_2Steps.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/sdxlLightning_2Steps.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/sdxlLightning_2Steps.safetensors'
# crystalClear_v10.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/crystalClear_v10.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/crystalClear_v10.safetensors'
# realvisxl-v50.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/realvisxl-v50.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50.safetensors'
# sdxlLightning_4Steps.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/sdxlLightning_4Steps.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/sdxlLightning_4Steps.safetensors'
# previewer_lora_weights.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/instantir/pytorch/default/2/previewer_lora_weights.bin' to '/kaggle/working/ComfyUI/models/InstantIR/models/previewer_lora_weights.bin'
# adapter.pt
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/instantir/pytorch/default/2/adapter.pt' to '/kaggle/working/ComfyUI/models/InstantIR/models/adapter.pt'
# aggregator.pt
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/instantir/pytorch/default/2/aggregator.pt' to '/kaggle/working/ComfyUI/models/InstantIR/models/aggregator.pt'
# fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors' to '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors'
# fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors'
# fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf'
# fluxFusionV24StepsGGUFNF4_V2NF4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf' to '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf'
# fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors'
# fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors'
# fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf'
# fluxFusionV24StepsGGUFNF4_V2NF4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf' to '/kaggle/working/ComfyUI/models/diffusion_models/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf'
# Text_Style_Autonomy-000005.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/Text_Style_Autonomy-000005.safetensors' to '/kaggle/working/ComfyUI/models/loras/Text_Style_Autonomy-000005.safetensors'
# perfect text title style v2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/perfect text title style v2.safetensors' to '/kaggle/working/ComfyUI/models/loras/perfect text title style v2.safetensors'
# aidmaImageUpgrader-FLUX-V0.2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/aidmaImageUpgrader-FLUX-V0.2.safetensors' to '/kaggle/working/ComfyUI/models/loras/aidmaImageUpgrader-FLUX-V0.2.safetensors'
# I-Type-You-Listen.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/I-Type-You-Listen.safetensors' to '/kaggle/working/ComfyUI/models/loras/I-Type-You-Listen.safetensors'
# ideogram1024-000006.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/ideogram1024-000006.safetensors' to '/kaggle/working/ComfyUI/models/loras/ideogram1024-000006.safetensors'
# Smash_Bros_Character_Reveal_FLUX-000021.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/Smash_Bros_Character_Reveal_FLUX-000021.safetensors' to '/kaggle/working/ComfyUI/models/loras/Smash_Bros_Character_Reveal_FLUX-000021.safetensors'
# Textimprover-FLUX-V0.4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/Textimprover-FLUX-V0.4.safetensors' to '/kaggle/working/ComfyUI/models/loras/Textimprover-FLUX-V0.4.safetensors'
# SDXL_skin texture style v5.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_skin texture style v5.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_skin texture style v5.safetensors'
# FLUX_detailifier_flux-000006.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_detailifier_flux-000006.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_detailifier_flux-000006.safetensors'
# FLUX_Rendered Face Detailer FLUX.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_Rendered Face Detailer FLUX.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_Rendered Face Detailer FLUX.safetensors'
# SDXL_Rendered Face Detailer v1.0.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_Rendered Face Detailer v1.0.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_Rendered Face Detailer v1.0.safetensors'
# FLUX_aidmaImageUprader-FLUX-v0.3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_aidmaImageUprader-FLUX-v0.3.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_aidmaImageUprader-FLUX-v0.3.safetensors'
# SDXL_perfection style.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_perfection style.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_perfection style.safetensors'
# SDXL_detailer_v5.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_detailer_v5.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_detailer_v5.safetensors'
# FLUX_Polyhedron_all_Kohya_ss-000001.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_Polyhedron_all_Kohya_ss-000001.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_Polyhedron_all_Kohya_ss-000001.safetensors'
# SDXL_skin texture style v4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_skin texture style v4.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_skin texture style v4.safetensors'
# SDXL_detailed.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_detailed.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_detailed.safetensors'
# FLUX_aidmaRealisticSkin-FLUX-v0.1.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_aidmaRealisticSkin-FLUX-v0.1.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_aidmaRealisticSkin-FLUX-v0.1.safetensors'
# SDXL_aidmaImageUpgraderSDXL-v0.3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_aidmaImageUpgraderSDXL-v0.3.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_aidmaImageUpgraderSDXL-v0.3.safetensors'
# [link_additional_models] Source directory does not exist: /kaggle/input/ccsr-safetensors/
# ============================================================
# Additional models linked successfully.
# ============================================================
# ============================================================
# Starting to set up ComfyUI...
# ------------------------------------------------------------
# Directory '/kaggle/working/ComfyUI/' exists
# Pulling latest changes...
# Fetching origin
# Updating 010954d2..312d5116
# Fast-forward
#  server.py | 7 +++----
#  1 file changed, 3 insertions(+), 4 deletions(-)
# From https://github.com/comfyanonymous/ComfyUI
#    010954d2..312d5116  master     -> origin/master
# Fetching origin
# Already up to date.
# ============================================================
# ComfyUI set up successfully.
# ------------------------------------------------------------
# Start Install packages list ...
# ============================================================
# Starting to install package from https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4...
# ------------------------------------------------------------
# Package https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4 path exist already, just updated
# ============================================================
# Package from https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4 installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/WASasquatch/was-node-suite-comfyui...
# ------------------------------------------------------------
# Package https://github.com/WASasquatch/was-node-suite-comfyui path exist already, just updated
# ============================================================
# Package from https://github.com/WASasquatch/was-node-suite-comfyui installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/rgthree/rgthree-comfy...
# ------------------------------------------------------------
# Package https://github.com/rgthree/rgthree-comfy path exist already, just updated
# ============================================================
# Package from https://github.com/rgthree/rgthree-comfy installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://codeberg.org/Gourieff/comfyui-reactor-node...
# ------------------------------------------------------------
# Package https://codeberg.org/Gourieff/comfyui-reactor-node path exist already, just updated
# ============================================================
# Package from https://codeberg.org/Gourieff/comfyui-reactor-node installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/BlenderNeko/ComfyUI_Noise...
# ------------------------------------------------------------
# Package https://github.com/BlenderNeko/ComfyUI_Noise path exist already, just updated
# ============================================================
# Package from https://github.com/BlenderNeko/ComfyUI_Noise installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/ltdrdata/ComfyUI-Impact-Pack...
# ------------------------------------------------------------
# Package https://github.com/ltdrdata/ComfyUI-Impact-Pack path exist already, just updated
# ============================================================
# Package from https://github.com/ltdrdata/ComfyUI-Impact-Pack installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/ltdrdata/ComfyUI-Impact-Subpack...
# ------------------------------------------------------------
# Package https://github.com/ltdrdata/ComfyUI-Impact-Subpack path exist already, just updated
# ============================================================
# Package from https://github.com/ltdrdata/ComfyUI-Impact-Subpack installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/yolain/ComfyUI-Easy-Use...
# ------------------------------------------------------------
# Package https://github.com/yolain/ComfyUI-Easy-Use path exist already, just updated
# ============================================================
# Package from https://github.com/yolain/ComfyUI-Easy-Use installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/kijai/ComfyUI-KJNodes...
# ------------------------------------------------------------
# Package https://github.com/kijai/ComfyUI-KJNodes path exist already, just updated
# ============================================================
# Package from https://github.com/kijai/ComfyUI-KJNodes installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/kijai/ComfyUI-Florence2...
# ------------------------------------------------------------
# Package https://github.com/kijai/ComfyUI-Florence2 path exist already, just updated
# ============================================================
# Package from https://github.com/kijai/ComfyUI-Florence2 installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/XLabs-AI/x-flux-comfyui...
# ------------------------------------------------------------
# Package https://github.com/XLabs-AI/x-flux-comfyui path exist already, just updated
# ============================================================
# Package from https://github.com/XLabs-AI/x-flux-comfyui installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/crystian/ComfyUI-Crystools...
# ------------------------------------------------------------
# Package https://github.com/crystian/ComfyUI-Crystools path exist already, just updated
# ============================================================
# Package from https://github.com/crystian/ComfyUI-Crystools installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes...
# ------------------------------------------------------------
# Package https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes path exist already, just updated
# ============================================================
# Package from https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/city96/ComfyUI-GGUF...
# ------------------------------------------------------------
# Package https://github.com/city96/ComfyUI-GGUF path exist already, just updated
# ============================================================
# Package from https://github.com/city96/ComfyUI-GGUF installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/cubiq/PuLID_ComfyUI...
# ------------------------------------------------------------
# Package https://github.com/cubiq/PuLID_ComfyUI path exist already, just updated
# ============================================================
# Package from https://github.com/cubiq/PuLID_ComfyUI installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/cubiq/ComfyUI_InstantID...
# ------------------------------------------------------------
# Package https://github.com/cubiq/ComfyUI_InstantID path exist already, just updated
# ============================================================
# Package from https://github.com/cubiq/ComfyUI_InstantID installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/cubiq/ComfyUI_IPAdapter_plus...
# ------------------------------------------------------------
# Package https://github.com/cubiq/ComfyUI_IPAdapter_plus path exist already, just updated
# ============================================================
# Package from https://github.com/cubiq/ComfyUI_IPAdapter_plus installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/comfyanonymous/ComfyUI_experiments...
# ------------------------------------------------------------
# Package https://github.com/comfyanonymous/ComfyUI_experiments path exist already, just updated
# ============================================================
# Package from https://github.com/comfyanonymous/ComfyUI_experiments installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/chengzeyi/Comfy-WaveSpeed...
# ------------------------------------------------------------
# Package https://github.com/chengzeyi/Comfy-WaveSpeed path exist already, just updated
# ============================================================
# Package from https://github.com/chengzeyi/Comfy-WaveSpeed installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/Fannovel16/comfyui_controlnet_aux...
# ------------------------------------------------------------
# Package https://github.com/Fannovel16/comfyui_controlnet_aux path exist already, just updated
# ============================================================
# Package from https://github.com/Fannovel16/comfyui_controlnet_aux installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/ShmuelRonen/ComfyUI-FreeMemory...
# ------------------------------------------------------------
# Package https://github.com/ShmuelRonen/ComfyUI-FreeMemory path exist already, just updated
# ============================================================
# Package from https://github.com/ShmuelRonen/ComfyUI-FreeMemory installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/jamesWalker55/comfyui-various...
# ------------------------------------------------------------
# Package https://github.com/jamesWalker55/comfyui-various path exist already, just updated
# ============================================================
# Package from https://github.com/jamesWalker55/comfyui-various installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/kijai/ComfyUI-SUPIR...
# ------------------------------------------------------------
# Package https://github.com/kijai/ComfyUI-SUPIR path exist already, just updated
# ============================================================
# Package from https://github.com/kijai/ComfyUI-SUPIR installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/klinter007/klinter_nodes...
# ------------------------------------------------------------
# Package https://github.com/klinter007/klinter_nodes path exist already, just updated
# ============================================================
# Package from https://github.com/klinter007/klinter_nodes installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/holchan/ComfyUI-ModelDownloader...
# ------------------------------------------------------------
# An error occurred while installing package from https://github.com/holchan/ComfyUI-ModelDownloader: Command '['git', 'clone', 'https://github.com/holchan/ComfyUI-ModelDownloader', '--recursive']' returned non-zero exit status 128.
# ============================================================
# Starting to install package from https://github.com/KoreTeknology/ComfyUI-Universal-Styler...
# ------------------------------------------------------------
# Package https://github.com/KoreTeknology/ComfyUI-Universal-Styler path exist already, just updated
# ============================================================
# Package from https://github.com/KoreTeknology/ComfyUI-Universal-Styler installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/marduk191/ComfyUI-Fluxpromptenhancer...
# ------------------------------------------------------------
# Package https://github.com/marduk191/ComfyUI-Fluxpromptenhancer path exist already, just updated
# ============================================================
# Package from https://github.com/marduk191/ComfyUI-Fluxpromptenhancer installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/fairy-root/Flux-Prompt-Generator...
# ------------------------------------------------------------
# Package https://github.com/fairy-root/Flux-Prompt-Generator path exist already, just updated
# ============================================================
# Package from https://github.com/fairy-root/Flux-Prompt-Generator installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/VykosX/ControlFlowUtils...
# ------------------------------------------------------------
# Package https://github.com/VykosX/ControlFlowUtils path exist already, just updated
# ============================================================
# Package from https://github.com/VykosX/ControlFlowUtils installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/godmt/ComfyUI-List-Utils...
# ------------------------------------------------------------
# Package https://github.com/godmt/ComfyUI-List-Utils path exist already, just updated
# ============================================================
# Package from https://github.com/godmt/ComfyUI-List-Utils installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/pythongosssss/ComfyUI-WD14-Tagger...
# ------------------------------------------------------------
# Package https://github.com/pythongosssss/ComfyUI-WD14-Tagger path exist already, just updated
# ============================================================
# Package from https://github.com/pythongosssss/ComfyUI-WD14-Tagger installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/miaoshouai/ComfyUI-Miaoshouai-Tagger...
# ------------------------------------------------------------
# Package https://github.com/miaoshouai/ComfyUI-Miaoshouai-Tagger path exist already, just updated
# ============================================================
# Package from https://github.com/miaoshouai/ComfyUI-Miaoshouai-Tagger installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/GraftingRayman/ComfyUI_GraftingRayman...
# ------------------------------------------------------------
# Package https://github.com/GraftingRayman/ComfyUI_GraftingRayman path exist already, just updated
# ============================================================
# Package from https://github.com/GraftingRayman/ComfyUI_GraftingRayman installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/pollockjj/ComfyUI-MultiGPU...
# ------------------------------------------------------------
# Package https://github.com/pollockjj/ComfyUI-MultiGPU path exist already, just updated
# ============================================================
# Package from https://github.com/pollockjj/ComfyUI-MultiGPU installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/dchatel/comfyui_facetools...
# ------------------------------------------------------------
# ...
# ============================================================
# Starting to install package from https://github.com/TheBill2001/comfyui-upscale-by-model...
# ------------------------------------------------------------
# Package https://github.com/TheBill2001/comfyui-upscale-by-model path exist already, just updated
# ============================================================
# Package from https://github.com/TheBill2001/comfyui-upscale-by-model installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/traugdor/ComfyUI-UltimateSDUpscale-GGUF...
# ------------------------------------------------------------
# Package https://github.com/traugdor/ComfyUI-UltimateSDUpscale-GGUF path exist already, just updated
# ============================================================
# Package from https://github.com/traugdor/ComfyUI-UltimateSDUpscale-GGUF installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/jags111/efficiency-nodes-comfyui...
# ------------------------------------------------------------
# Package https://github.com/jags111/efficiency-nodes-comfyui path exist already, just updated
# ============================================================
# Package from https://github.com/jags111/efficiency-nodes-comfyui installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/kijai/ComfyUI-segment-anything-2...
# ------------------------------------------------------------
# Package https://github.com/kijai/ComfyUI-segment-anything-2 path exist already, just updated
# ============================================================
# Package from https://github.com/kijai/ComfyUI-segment-anything-2 installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/Extraltodeus/ComfyUI-AutomaticCFG...
# ------------------------------------------------------------
# Package https://github.com/Extraltodeus/ComfyUI-AutomaticCFG path exist already, just updated
# ============================================================
# Package from https://github.com/Extraltodeus/ComfyUI-AutomaticCFG installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/ltdrdata/ComfyUI-Inspire-Pack...
# ------------------------------------------------------------
# Package https://github.com/ltdrdata/ComfyUI-Inspire-Pack path exist already, just updated
# ============================================================
# Package from https://github.com/ltdrdata/ComfyUI-Inspire-Pack installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/evanspearman/ComfyMath...
# ------------------------------------------------------------
# Package https://github.com/evanspearman/ComfyMath path exist already, just updated
# ============================================================
# Package from https://github.com/evanspearman/ComfyMath installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/Derfuu/Derfuu_ComfyUI_ModdedNodes...
# ------------------------------------------------------------
# Package https://github.com/Derfuu/Derfuu_ComfyUI_ModdedNodes path exist already, just updated
# ============================================================
# Package from https://github.com/Derfuu/Derfuu_ComfyUI_ModdedNodes installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/storyicon/comfyui_segment_anything...
# ------------------------------------------------------------
# Package https://github.com/storyicon/comfyui_segment_anything path exist already, just updated
# ============================================================
# Package from https://github.com/storyicon/comfyui_segment_anything installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/PrunaAI/ComfyUI_pruna...
# ------------------------------------------------------------
# Package https://github.com/PrunaAI/ComfyUI_pruna path exist already, just updated
# ============================================================
# Package from https://github.com/PrunaAI/ComfyUI_pruna installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/zhangp365/ComfyUI-utils-nodes...
# ------------------------------------------------------------
# Package https://github.com/zhangp365/ComfyUI-utils-nodes path exist already, just updated
# ============================================================
# Package from https://github.com/zhangp365/ComfyUI-utils-nodes installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/pythongosssss/ComfyUI-Custom-Scripts...
# ------------------------------------------------------------
# Package https://github.com/pythongosssss/ComfyUI-Custom-Scripts path exist already, just updated
# ============================================================
# Package from https://github.com/pythongosssss/ComfyUI-Custom-Scripts installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/revirevy/Comfyui_saveimage_imgbb...
# ------------------------------------------------------------
# Package https://github.com/revirevy/Comfyui_saveimage_imgbb path exist already, just updated
# ============================================================
# Package from https://github.com/revirevy/Comfyui_saveimage_imgbb installed successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to install package from https://github.com/ltdrdata/ComfyUI-Manager...
# ------------------------------------------------------------
# Package https://github.com/ltdrdata/ComfyUI-Manager path exist already, just updated
# ============================================================
# Package from https://github.com/ltdrdata/ComfyUI-Manager installed successfully.
# ------------------------------------------------------------
# All Packages list installed
#  ==========  DONE  ==========
# ============================================================
# Starting to set up ComfyUI...
# ------------------------------------------------------------
# Directory '/kaggle/working/ComfyUI/' exists
# Pulling latest changes...
# Fetching origin
# Already up to date.
# Fetching origin
# Already up to date.
# ============================================================
# ComfyUI set up successfully.
# ------------------------------------------------------------
# ============================================================
# Starting ComfyUI instances...
# ------------------------------------------------------------
# ============================================================
# ComfyUI instances started successfully.
# ------------------------------------------------------------
# ============================================================
# Starting Playit agent...
# ------------------------------------------------------------
# rights-leader.gl.at.ply.gg:16606 => 127.0.0.1:8188 (proto: Tcp, port count: 1)
# 8playit (v0.15.26): 1748858547240 tunnel running, 2 tunnels registered
#
#
# TUNNELS
# city-costa.gl.at.ply.gg:44665 => 127.0.0.1:8189 (proto: Both, port count: 1)
# rights-leader.gl.at.ply.gg:16606 => 127.0.0.1:8188 (proto: Tcp, port count: 1)
# 8playit (v0.15.26): 1748858550389 tunnel running, 2 tunnels registered
#
#
# TUNNELS
# city-costa.gl.at.ply.gg:44665 => 127.0.0.1:8189 (proto: Both, port count: 1)
# rights-leader.gl.at.ply.gg:16606 => 127.0.0.1:8188 (proto: Tcp, port count: 1)
# 8playit (v0.15.26): 1748858553475 tunnel running, 2 tunnels registered
#
#
# TUNNELS
# city-costa.gl.at.ply.gg:44665 => 127.0.0.1:8189 (proto: Both, port count: 1)
# rights-leader.gl.at.ply.gg:16606 => 127.0.0.1:8188 (proto: Tcp, port count: 1)
# 8no command provided, doing auto run8Visit link to setup https://playit.gg/claim/ef39300594
# ..........
#
# ============================================================
# Playit agent started successfully.
# ------------------------------------------------------------
# Downloading Antelopev2 model...
# Downloading: 100%|██████████| 344M/344M [00:04<00:00, 75.3MB/s]
# Download completed. Extracting files...
# Extraction completed. Antelopev2 model is ready.
# Installing aria2...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 87 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 129184 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# aria2 installed successfully.
# Downloading file 1/4: fan2_68_landmark.onnx...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4c319e|OK  |       0B/s|/kaggle/working/ComfyUI/models/landmarks/fan2_68_landmark.onnx
#
# Status Legend:
# (OK):download completed.
# Download completed for fan2_68_landmark.onnx.
# Downloading file 2/4: 79999_iter.pth...
# [#582193 0B/0B CN:1 DL:0B]
# [#582193 0B/0B CN:1 DL:0B]
# [#582193 0B/0B CN:1 DL:0B]
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 582193|OK  |       0B/s|/kaggle/working/ComfyUI/models/bisenet/79999_iter.pth
#
# Status Legend:
# (OK):download completed.
# Download completed for 79999_iter.pth.
# Downloading file 3/4: face_yolov8m.pt...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9bdc02|OK  |       0B/s|/kaggle/working/ComfyUI/models/ultralytics/bbox/face_yolov8m.pt
#
# Status Legend:
# (OK):download completed.
# Download completed for face_yolov8m.pt.
# Downloading file 4/4: control_v11p_sd15_inpaint_fp16.safetensors...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5f3027|OK  |       0B/s|/kaggle/working/ComfyUI/models/controlnet//control_v11p_sd15_inpaint_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# Download completed for control_v11p_sd15_inpaint_fp16.safetensors.
# 0 - https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/reswapper_256.onnx?download=true
# reswapper_256.onnx
# Downloading file 1/4: control_v11p_sd15_inpaint_fp16.safetensors...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fcc5f3|OK  |       0B/s|/kaggle/working/ComfyUI/models/reswapper//reswapper_256.onnx
#
# Status Legend:
# (OK):download completed.
# Download completed for reswapper_256.onnx.
# 1 -     https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/reswapper_128.onnx?download=true
# reswapper_128.onnx
# Downloading file 2/4: control_v11p_sd15_inpaint_fp16.safetensors...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 53b336|ERR |        n/a|/kaggle/working/ComfyUI/models/reswapper//reswapper_128.onnx
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# Failed to download reswapper_128.onnx: Command 'aria2c --console-log-level=error -c -x 16 -s 16 -k 1M '    https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/reswapper_128.onnx?download=true' -d '/kaggle/working/ComfyUI/models/reswapper/' -o 'reswapper_128.onnx'' returned non-zero exit status 1.
# 2 -     https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/inswapper_128.onnx?download=true
# inswapper_128.onnx
# Downloading file 3/4: control_v11p_sd15_inpaint_fp16.safetensors...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 59aa82|ERR |        n/a|/kaggle/working/ComfyUI/models/reswapper//inswapper_128.onnx
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# Failed to download inswapper_128.onnx: Command 'aria2c --console-log-level=error -c -x 16 -s 16 -k 1M '    https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/inswapper_128.onnx?download=true' -d '/kaggle/working/ComfyUI/models/reswapper/' -o 'inswapper_128.onnx'' returned non-zero exit status 1.
# All downloads completed.
# ============================================================
# Starting scheduler...
# ------------------------------------------------------------
# ============================================================
# Executed
# 2025-06-02 11:46:51.439470
# ------------------------------------------------------------
# ============================================================
# Scheduler started in background. It will execute the first cell every 1 minute.
# ------------------------------------------------------------

# %%
# !tail /kaggle/working/ComfyUI/logs/playit.log | grep claim
# Out:
#    2344 ?        RLl    0:42  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2371 ?        RLl    0:35  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2636 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#    2638 pts/0    R+     0:00      \_ grep -i -E comfy|main
#    2412 ?        Sl     0:00 /kaggle/working/ComfyUI/playit-linux-amd64
# 8no command provided, doing auto run8Visit link to setup https://playit.gg/claim/ef393005948Visit link to setup https://playit.gg/claim/ef393005948Visit link to setup https://playit.gg/claim/ef393005948Visit link to setup https://playit.gg/claim/ef39300594
# ============================================================
# ------------------------------------------------------------

# %%
    # Link models
    link_models()

    # link_additional_models
    link_additional_models()
# Out:
# ============================================================
# Starting to link models...
# ------------------------------------------------------------
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/clip-gmp-vit-l-14/tensorflow2/default/1/model.safetensors' to '/kaggle/working/ComfyUI/models/clip/CLIP_gmp_VIT_L_14.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/t5xxl_fp16.safetensors/tensorflow2/default/1/t5xxl_fp16.safetensors' to '/kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux-vae-safetensors/pytorch/default/1/ae.safetensors' to '/kaggle/working/ComfyUI/models/vae/FLuX_ae.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/florence2/transformers/default/1/Florence2_model_3/model.safetensors' to '/kaggle/working/ComfyUI/models/LLM/Florence_model_3.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/florence2/transformers/default/1/Florence2_model_2/model.safetensors' to '/kaggle/working/ComfyUI/models/LLM/Florence_model_2.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux1devnf46stepsnsfw/pytorch/default/1/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/8stepscrearthyperfluxdevbnb_v24hyperdevfp8unet_/pytorch/default/1/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors' to '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/creart-hyper-flux-dev-gguf-q4_0/gguf/default/1/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf' to '/kaggle/working/ComfyUI/models/unet/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/unet/gguf/flux1-dev-q4_k_s/1/flux1-dev-Q4_K_S.gguf' to '/kaggle/working/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/albedobaseXL_v3Mini.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/alimama-flux-turbo-lora/pytorch/default/1/diffusion_pytorch_model.safetensors' to '/kaggle/working/ComfyUI/models/loras/alimama-flux-turbo-lora.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/fluxArtfusion4Steps_v12.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin' to '/kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/controlnet_instantid_model.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/instantid/LeInstantID_ControlNet_model.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xnomosunidat_upscaler.safetensors' to '/kaggle/working/ComfyUI/models/upscale_models/4xnomosunidat_upscaler.safetensors'
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flashface/pytorch/default/1/flashface.ckpt' to '/kaggle/working/ComfyUI/models/flashface/flashface.ckpt'
# ============================================================
# Models linked successfully.
# ------------------------------------------------------------
# ============================================================
# Starting to link additional models...
# ============================================================
# RealESRGAN_x4plus.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/RealESRGAN_x4plus.pth' to '/kaggle/working/ComfyUI/models/upscale_models/RealESRGAN_x4plus.pth'
# 1xDeJPG_OmniSR.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/1xDeJPG_OmniSR.pth' to '/kaggle/working/ComfyUI/models/upscale_models/1xDeJPG_OmniSR.pth'
# 1xRedImage10000.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/1xRedImage10000.pth' to '/kaggle/working/ComfyUI/models/upscale_models/1xRedImage10000.pth'
# DPED.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/DPED.pth' to '/kaggle/working/ComfyUI/models/upscale_models/DPED.pth'
# BSRGANx2.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/BSRGANx2.pth' to '/kaggle/working/ComfyUI/models/upscale_models/BSRGANx2.pth'
# 4xLSDIRplusC.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplusC.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplusC.pth'
# 4xNomosUniDAT_otf.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomosUniDAT_otf.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomosUniDAT_otf.pth'
# RealESRGAN_x2plus.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/RealESRGAN_x2plus.pth' to '/kaggle/working/ComfyUI/models/upscale_models/RealESRGAN_x2plus.pth'
# 4xNomos8kSC.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomos8kSC.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomos8kSC.pth'
# 4xLSDIR.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIR.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIR.pth'
# DF2K.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/DF2K.pth' to '/kaggle/working/ComfyUI/models/upscale_models/DF2K.pth'
# 4x_NickelbackFS_72000_G.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4x_NickelbackFS_72000_G.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4x_NickelbackFS_72000_G.pth'
# 4xLSDIRplus.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplus.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplus.pth'
# 4xNomosWebPhoto_esrgan.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomosWebPhoto_esrgan.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomosWebPhoto_esrgan.pth'
# 4xLSDIRplusR.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplusR.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplusR.pth'
# 4x_RealisticRescaler_100000_G.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4x_RealisticRescaler_100000_G.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4x_RealisticRescaler_100000_G.pth'
# 4xNomos2_otf_esrgan.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xNomos2_otf_esrgan.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xNomos2_otf_esrgan.pth'
# 4xLSDIRplusN.pth
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xLSDIRplusN.pth' to '/kaggle/working/ComfyUI/models/upscale_models/4xLSDIRplusN.pth'
# t5-v1_1-xxl-encoder-Q8_0.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf' to '/kaggle/working/ComfyUI/models/clip/t5-v1_1-xxl-encoder-Q8_0.gguf'
# t5-v1_1-xxl-encoder-f16.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-f16.gguf' to '/kaggle/working/ComfyUI/models/clip/t5-v1_1-xxl-encoder-f16.gguf'
# ip-adapter-plus_sdxl_vit-h.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-plus_sdxl_vit-h.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-plus_sdxl_vit-h.safetensors'
# controlnet-sd-xl-1.0-softedge-dexined.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-sd-xl-1.0-softedge-dexined.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-sd-xl-1.0-softedge-dexined.safetensors'
# ip-adapter-faceid-plusv2_sdxl.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-faceid-plusv2_sdxl.bin' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-faceid-plusv2_sdxl.bin'
# controlnet-v1e-sdxl-depth.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-v1e-sdxl-depth.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-v1e-sdxl-depth.safetensors'
# depth-zoe-xl-v1.0-controlnet.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/depth-zoe-xl-v1.0-controlnet.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/depth-zoe-xl-v1.0-controlnet.safetensors'
# CONTROLNET_INSTANTID_model.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/CONTROLNET_INSTANTID_model.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/CONTROLNET_INSTANTID_model.safetensors'
# OpenPoseXL2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/OpenPoseXL2.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/OpenPoseXL2.safetensors'
# ip-adapter_sdxl_vit-h.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter_sdxl_vit-h.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter_sdxl_vit-h.safetensors'
# ip-adapter.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter.bin' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter.bin'
# ip-adapter-plus-face_sdxl_vit-h.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-plus-face_sdxl_vit-h.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-plus-face_sdxl_vit-h.safetensors'
# controlnet-canny-sdxl-1.0_model_V2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-canny-sdxl-1.0_model_V2.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-canny-sdxl-1.0_model_V2.safetensors'
# diffusion_pytorch_model_twins.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/diffusion_pytorch_model_twins.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/diffusion_pytorch_model_twins.safetensors'
# ip-adapter-faceid_sdxl.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter-faceid_sdxl.bin' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter-faceid_sdxl.bin'
# ip-adapter_sdxl.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/ip-adapter_sdxl.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/ip-adapter_sdxl.safetensors'
# controlnet-union-sdxl-1.0_base_model.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-union-sdxl-1.0_base_model.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-union-sdxl-1.0_base_model.safetensors'
# controlnet-sd-xl-1.0-depth-16bit-zoe.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/controlnet-sd-xl-1.0-depth-16bit-zoe.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/controlnet-sd-xl-1.0-depth-16bit-zoe.safetensors'
# contronet-union-sdxl_model_promax.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/sdxl_controlnets/pytorch/default/4/contronet-union-sdxl_model_promax.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/contronet-union-sdxl_model_promax.safetensors'
# [link_additional_models] Source directory does not exist: /kaggle/input/pulid-model/pytorch/default/4/
# INSTANTID_ip-adapter.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix_instantid_ipadapter/pytorch/default/1/INSTANTID_ip-adapter.bin' to '/kaggle/working/ComfyUI/models/controlnet/INSTANTID_ip-adapter.bin'
# INSTANTID_ip-adapter.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix_instantid_ipadapter/pytorch/default/1/INSTANTID_ip-adapter.bin' to '/kaggle/working/ComfyUI/models/instantid/INSTANTID_ip-adapter.bin'
# FLUX_ Upscaler_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_ Upscaler_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_ Upscaler_Jasperai.safetensors'
# FLUX_Depth_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Depth_Jasperai.safetensors'
# FLUX_Union_Pro_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Union_Pro_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Union_Pro_Shakkerai.safetensors'
# FLUX_Canny_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Canny_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Canny_Shakkerai.safetensors'
# FLUX_Depth_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Depth_Shakkerai.safetensors'
# flux-hed-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-hed-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/flux-hed-controlnet-v3.safetensors'
# flux-depth-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-depth-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/flux-depth-controlnet-v3.safetensors'
# flux-canny-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-canny-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/flux-canny-controlnet-v3.safetensors'
# FLUX_Surface_Normal_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Surface_Normal_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/FLUX_Surface_Normal_Jasperai.safetensors'
# SDXL-Openpose.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/SDXL-Openpose.safetensors' to '/kaggle/working/ComfyUI/models/controlnet/SDXL-Openpose.safetensors'
# FLUX_ Upscaler_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_ Upscaler_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_ Upscaler_Jasperai.safetensors'
# FLUX_Depth_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Depth_Jasperai.safetensors'
# FLUX_Union_Pro_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Union_Pro_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Union_Pro_Shakkerai.safetensors'
# FLUX_Canny_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Canny_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Canny_Shakkerai.safetensors'
# FLUX_Depth_Shakkerai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Depth_Shakkerai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Depth_Shakkerai.safetensors'
# flux-hed-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-hed-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/flux-hed-controlnet-v3.safetensors'
# flux-depth-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-depth-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/flux-depth-controlnet-v3.safetensors'
# flux-canny-controlnet-v3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/flux-canny-controlnet-v3.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/flux-canny-controlnet-v3.safetensors'
# FLUX_Surface_Normal_Jasperai.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/FLUX_Surface_Normal_Jasperai.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/FLUX_Surface_Normal_Jasperai.safetensors'
# SDXL-Openpose.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/SDXL-Openpose.safetensors' to '/kaggle/working/ComfyUI/models/xlabs/controlnets/SDXL-Openpose.safetensors'
# dmd2_sdxl_4step_unet_fp16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_4step_unet_fp16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/dmd2_sdxl_4step_unet_fp16.safetensors'
# dmd2_sdxl_1step_unet_fp16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_1step_unet_fp16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/dmd2_sdxl_1step_unet_fp16.safetensors'
# dmd2_sdxl_4step_lora_fp16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_4step_lora_fp16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/dmd2_sdxl_4step_lora_fp16.safetensors'
# Juggernaut-XI-byRunDiffusion-Lightning.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/juggernaut/pytorch/default/1/Juggernaut-XI-byRunDiffusion-Lightning.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/Juggernaut-XI-byRunDiffusion-Lightning.safetensors'
# Juggernaut-XI-byRunDiffusion.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/juggernaut/pytorch/default/1/Juggernaut-XI-byRunDiffusion.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/Juggernaut-XI-byRunDiffusion.safetensors'
# JuggernautXRundiffusion_Hyper.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/juggernaut/pytorch/default/1/JuggernautXRundiffusion_Hyper.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/JuggernautXRundiffusion_Hyper.safetensors'
# Epicrealismxl_Hades.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/Epicrealismxl_Hades.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/Epicrealismxl_Hades.safetensors'
# SG161222_RealVisXL_V5_0_Lightning.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/SG161222_RealVisXL_V5_0_Lightning.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/SG161222_RealVisXL_V5_0_Lightning.safetensors'
# hephaistosNextgen_v10ExperimentalBF16.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/hephaistosNextgen_v10ExperimentalBF16.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/hephaistosNextgen_v10ExperimentalBF16.safetensors'
# sdxlLightning_2Steps.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/sdxlLightning_2Steps.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/sdxlLightning_2Steps.safetensors'
# crystalClear_v10.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/crystalClear_v10.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/crystalClear_v10.safetensors'
# realvisxl-v50.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/realvisxl-v50.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50.safetensors'
# sdxlLightning_4Steps.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/realvisxl-v50/pytorch/default/3/sdxlLightning_4Steps.safetensors' to '/kaggle/working/ComfyUI/models/checkpoints/sdxlLightning_4Steps.safetensors'
# previewer_lora_weights.bin
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/instantir/pytorch/default/2/previewer_lora_weights.bin' to '/kaggle/working/ComfyUI/models/InstantIR/models/previewer_lora_weights.bin'
# adapter.pt
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/instantir/pytorch/default/2/adapter.pt' to '/kaggle/working/ComfyUI/models/InstantIR/models/adapter.pt'
# aggregator.pt
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/instantir/pytorch/default/2/aggregator.pt' to '/kaggle/working/ComfyUI/models/InstantIR/models/aggregator.pt'
# fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors' to '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors'
# fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors'
# fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf'
# fluxFusionV24StepsGGUFNF4_V2NF4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors' to '/kaggle/working/ComfyUI/models/unet/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf' to '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf'
# fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2Fp8.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/8StepsCreartHyperFlux_v40HyperDevFp8Unet.safetensors'
# fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2NF4AIO.safetensors'
# fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2GGUFQ4KS.gguf'
# fluxFusionV24StepsGGUFNF4_V2NF4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors' to '/kaggle/working/ComfyUI/models/diffusion_models/fluxFusionV24StepsGGUFNF4_V2NF4.safetensors'
# 8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/nix-flux-fusion-models/pytorch/default/1/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf' to '/kaggle/working/ComfyUI/models/diffusion_models/8StepsCreartHyperFlux_v40HyperDevGgufQ40.gguf'
# Text_Style_Autonomy-000005.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/Text_Style_Autonomy-000005.safetensors' to '/kaggle/working/ComfyUI/models/loras/Text_Style_Autonomy-000005.safetensors'
# perfect text title style v2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/perfect text title style v2.safetensors' to '/kaggle/working/ComfyUI/models/loras/perfect text title style v2.safetensors'
# aidmaImageUpgrader-FLUX-V0.2.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/aidmaImageUpgrader-FLUX-V0.2.safetensors' to '/kaggle/working/ComfyUI/models/loras/aidmaImageUpgrader-FLUX-V0.2.safetensors'
# I-Type-You-Listen.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/I-Type-You-Listen.safetensors' to '/kaggle/working/ComfyUI/models/loras/I-Type-You-Listen.safetensors'
# ideogram1024-000006.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/ideogram1024-000006.safetensors' to '/kaggle/working/ComfyUI/models/loras/ideogram1024-000006.safetensors'
# Smash_Bros_Character_Reveal_FLUX-000021.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/Smash_Bros_Character_Reveal_FLUX-000021.safetensors' to '/kaggle/working/ComfyUI/models/loras/Smash_Bros_Character_Reveal_FLUX-000021.safetensors'
# Textimprover-FLUX-V0.4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/flux_loras/pytorch/default/1/Textimprover-FLUX-V0.4.safetensors' to '/kaggle/working/ComfyUI/models/loras/Textimprover-FLUX-V0.4.safetensors'
# SDXL_skin texture style v5.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_skin texture style v5.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_skin texture style v5.safetensors'
# FLUX_detailifier_flux-000006.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_detailifier_flux-000006.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_detailifier_flux-000006.safetensors'
# FLUX_Rendered Face Detailer FLUX.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_Rendered Face Detailer FLUX.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_Rendered Face Detailer FLUX.safetensors'
# SDXL_Rendered Face Detailer v1.0.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_Rendered Face Detailer v1.0.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_Rendered Face Detailer v1.0.safetensors'
# FLUX_aidmaImageUprader-FLUX-v0.3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_aidmaImageUprader-FLUX-v0.3.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_aidmaImageUprader-FLUX-v0.3.safetensors'
# SDXL_perfection style.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_perfection style.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_perfection style.safetensors'
# SDXL_detailer_v5.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_detailer_v5.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_detailer_v5.safetensors'
# FLUX_Polyhedron_all_Kohya_ss-000001.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_Polyhedron_all_Kohya_ss-000001.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_Polyhedron_all_Kohya_ss-000001.safetensors'
# SDXL_skin texture style v4.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_skin texture style v4.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_skin texture style v4.safetensors'
# SDXL_detailed.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_detailed.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_detailed.safetensors'
# FLUX_aidmaRealisticSkin-FLUX-v0.1.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/FLUX_aidmaRealisticSkin-FLUX-v0.1.safetensors' to '/kaggle/working/ComfyUI/models/loras/FLUX_aidmaRealisticSkin-FLUX-v0.1.safetensors'
# SDXL_aidmaImageUpgraderSDXL-v0.3.safetensors
# >> [xlinkthis]: Create symlink from
#  '/kaggle/input/loras_diff_comfy/pytorch/default/1/SDXL_aidmaImageUpgraderSDXL-v0.3.safetensors' to '/kaggle/working/ComfyUI/models/loras/SDXL_aidmaImageUpgraderSDXL-v0.3.safetensors'
# [link_additional_models] Source directory does not exist: /kaggle/input/ccsr-safetensors/
# ============================================================
# Additional models linked successfully.
# ============================================================

# %%
# !ps fax
# Out:
#     PID TTY      STAT   TIME COMMAND
#      53 ?        Ss     0:02 /opt/bin/nvidia-smi -l 1 --query-gpu=index,utilization.gpu,memory.used,
#       1 ?        Ssl    0:14 /usr/bin/python3 /usr/local/bin/jupyter-notebook --ip=* --NotebookApp.b
#      35 ?        Ssl    0:16 /usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter
#    2344 ?        SLl    1:29  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2402 ?        Sl     0:05  |   \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/torch/
#    2424 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2425 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2427 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2429 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2371 ?        SLl   12:41  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2421 ?        Sl     0:05  |   \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/torch/
#    2443 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2445 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2447 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2449 ?        Sl     0:00  |       \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/to
#    2802 pts/0    Rs+    0:00  \_ ps fax
#      58 ?        Sl     0:07 /usr/bin/python3 -m pylsp
#    2741 ?        S      0:00  \_ /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/jedi/infer
#     921 ?        Z      0:00 [git] <defunct>
#    2412 ?        Sl     0:02 /kaggle/working/ComfyUI/playit-linux-amd64

# %%
# %ls -ltrha ./models/controlnet/insta

# %%
im

# %%
from huggingface_hub import hf_hub_download
unet = hf_hub_download(
            repo_id="refiners/juggernaut.reborn.sd1_5.unet",
            filename="model.safetensors")
# Out:
# model.safetensors:   0%|          | 0.00/1.72G [00:00<?, ?B/s]

# %%
# !ln -s $unet /kaggle/working/ComfyUI/models/checkpoints/juggernaut.reborn.sd1_5_unet.safetensors

# %%
hf_hub_download(repo_id="philz1337x/loras",filename="more_details.safetensors",local_dir="/kaggle/working/ComfyUI/models/loras")
# Out:
# more_details.safetensors:   0%|          | 0.00/9.55M [00:00<?, ?B/s]
# '/kaggle/working/ComfyUI/models/loras/more_details.safetensors'
# ============================================================
# Executed
# 2025-06-02 12:00:53.186528
# ------------------------------------------------------------
#    2344 ?        SLl    1:29  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2371 ?        SLl   12:37  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2797 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#    2799 pts/0    S+     0:00      \_ grep -i -E comfy|main
#    2412 ?        Sl     0:02 /kaggle/working/ComfyUI/playit-linux-amd64
# ============================================================
# ------------------------------------------------------------

# %%
hf_hub_download(
                repo_id="philz1337x/loras",
                filename="SDXLrender_v2.0.safetensors"
                ,local_dir="/kaggle/working/ComfyUI/models/loras"
            )
# Out:
# SDXLrender_v2.0.safetensors:   0%|          | 0.00/181M [00:00<?, ?B/s]
# '/kaggle/working/ComfyUI/models/loras/SDXLrender_v2.0.safetensors'

# %%
# !ls -ltrha /kaggle/working/ComfyUI/models/checkpoints
# Out:
# total 80K
# -rw-r--r--  1 root root    0 Jun  2 11:32 put_checkpoints_here
# lrwxrwxrwx  1 root root  104 Jun  2 11:38 flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors -> /kaggle/input/flux1devnf46stepsnsfw/pytorch/default/1/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors
# lrwxrwxrwx  1 root root   89 Jun  2 11:38 albedobaseXL_v3Mini.safetensors -> /kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors
# lrwxrwxrwx  1 root root   91 Jun  2 11:38 fluxArtfusion4Steps_v12.safetensors -> /kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors
# lrwxrwxrwx  1 root root   74 Jun  2 11:38 dmd2_sdxl_4step_unet_fp16.safetensors -> /kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_4step_unet_fp16.safetensors
# lrwxrwxrwx  1 root root   74 Jun  2 11:38 dmd2_sdxl_4step_lora_fp16.safetensors -> /kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_4step_lora_fp16.safetensors
# lrwxrwxrwx  1 root root   74 Jun  2 11:38 dmd2_sdxl_1step_unet_fp16.safetensors -> /kaggle/input/dmd2/pytorch/default/1/dmd2_sdxl_1step_unet_fp16.safetensors
# lrwxrwxrwx  1 root root   84 Jun  2 11:38 JuggernautXRundiffusion_Hyper.safetensors -> /kaggle/input/juggernaut/pytorch/default/1/JuggernautXRundiffusion_Hyper.safetensors
# lrwxrwxrwx  1 root root   83 Jun  2 11:38 Juggernaut-XI-byRunDiffusion.safetensors -> /kaggle/input/juggernaut/pytorch/default/1/Juggernaut-XI-byRunDiffusion.safetensors
# lrwxrwxrwx  1 root root   93 Jun  2 11:38 Juggernaut-XI-byRunDiffusion-Lightning.safetensors -> /kaggle/input/juggernaut/pytorch/default/1/Juggernaut-XI-byRunDiffusion-Lightning.safetensors
# lrwxrwxrwx  1 root root   91 Jun  2 11:38 SG161222_RealVisXL_V5_0_Lightning.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/SG161222_RealVisXL_V5_0_Lightning.safetensors
# lrwxrwxrwx  1 root root   78 Jun  2 11:38 sdxlLightning_4Steps.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/sdxlLightning_4Steps.safetensors
# lrwxrwxrwx  1 root root   78 Jun  2 11:38 sdxlLightning_2Steps.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/sdxlLightning_2Steps.safetensors
# lrwxrwxrwx  1 root root   71 Jun  2 11:38 realvisxl-v50.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/realvisxl-v50.safetensors
# lrwxrwxrwx  1 root root   95 Jun  2 11:38 hephaistosNextgen_v10ExperimentalBF16.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/hephaistosNextgen_v10ExperimentalBF16.safetensors
# lrwxrwxrwx  1 root root   77 Jun  2 11:38 Epicrealismxl_Hades.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/Epicrealismxl_Hades.safetensors
# lrwxrwxrwx  1 root root   74 Jun  2 11:38 crystalClear_v10.safetensors -> /kaggle/input/realvisxl-v50/pytorch/default/3/crystalClear_v10.safetensors
# drwxr-xr-x 37 root root 4.0K Jun  2 11:47 ..
# lrwxrwxrwx  1 root root  144 Jun  2 11:54 model.safetensors -> /root/.cache/huggingface/hub/models--refiners--juggernaut.reborn.sd1_5.unet/snapshots/9a76f7d49b9d294dd544b86939f66a69fac163b8/model.safetensors
# lrwxrwxrwx  1 root root  144 Jun  2 11:55 juggernaut.reborn.sd1_5_unet.safetensors -> /root/.cache/huggingface/hub/models--refiners--juggernaut.reborn.sd1_5.unet/snapshots/9a76f7d49b9d294dd544b86939f66a69fac163b8/model.safetensors
# drwxr-xr-x  2 root root 4.0K Jun  2 11:55 .
# ============================================================
# Executed
# 2025-06-02 11:55:52.575221
# ------------------------------------------------------------
#    2344 ?        SLl    1:28  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2371 ?        SLl    6:47  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2761 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#    2763 pts/0    S+     0:00      \_ grep -i -E comfy|main
#    2412 ?        Sl     0:01 /kaggle/working/ComfyUI/playit-linux-amd64
# ============================================================
# ------------------------------------------------------------
# ============================================================
# Executed
# 2025-06-02 11:56:52.696464
# ------------------------------------------------------------
#    2344 ?        SLl    1:28  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2371 ?        SLl    8:01  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2768 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#    2770 pts/0    S+     0:00      \_ grep -i -E comfy|main
#    2412 ?        Sl     0:01 /kaggle/working/ComfyUI/playit-linux-amd64
# ============================================================
# ------------------------------------------------------------
# ============================================================
# Executed
# 2025-06-02 11:57:52.817814
# ------------------------------------------------------------
#    2344 ?        SLl    1:29  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2371 ?        SLl    9:15  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2775 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#    2777 pts/0    S+     0:00      \_ grep -i -E comfy|main
#    2412 ?        Sl     0:01 /kaggle/working/ComfyUI/playit-linux-amd64
# ============================================================
# ------------------------------------------------------------
# ============================================================
# Executed
# 2025-06-02 11:58:52.937243
# ------------------------------------------------------------
#    2344 ?        SLl    1:29  \_ /usr/bin/python3 main.py --cuda-device 0 --port 8188 --fp8_e4m3fn-t
#    2371 ?        SLl   10:23  \_ /usr/bin/python3 main.py --cuda-device 1 --port 8189 --fp8_e4m3fn-t
#    2783 pts/0    Ss+    0:00  \_ /bin/bash -c ps fax| grep -i -E 'comfy|main'
#    2785 pts/0    S+     0:00      \_ grep -i -E comfy|main
#    2412 ?        Sl     0:02 /kaggle/working/ComfyUI/playit-linux-amd64
# ============================================================
# ------------------------------------------------------------

# %%
??start_comfyui_instances

# %%
    os.chdir("/kaggle/working/ComfyUI/")
    # xP1 = subprocess.Popen([sys.executable, "main.py", "--cuda-device", "0", "--port", "8188", "--fp8_e4m3fn-text-enc","--fp8_e4m3fn-unet", "--highvram"]) #--fp8_e4m3fn-text-enc --fp8_e4m3fn-unet
    os.makedirs("/kaggle/working/ComfyUI/logs", exist_ok=True)
    with open("/kaggle/working/ComfyUI/logs/comfy_8188.log", "a") as logfile:
        xP1 = subprocess.Popen(
            [sys.executable, "main.py", "--cuda-device", "0", "--port", "8188", 
             "--fp8_e4m3fn-text-enc", "--fp8_e4m3fn-unet", "--highvram"],
            stdout=logfile,
            stderr=subprocess.STDOUT
        )
    # time.sleep(10)
    with open("/kaggle/working/ComfyUI/logs/comfy_8189.log", "a") as logfile:
        xP2 = subprocess.Popen([sys.executable, "main.py", "--cuda-device", "1", "--port", "8189", "--fp8_e4m3fn-text-enc","--fp8_e4m3fn-unet", "--highvram"]
                                          ,stdout=logfile, stderr=subprocess.STDOUT) #, "--highvram"])
    # time.sleep(10)
    print("="*60, "ComfyUI instances started successfully.", "-"*60, sep="\n")

# %%
os.makedirs("models/ipadapter")

# %%
# !ln -s /kaggle/input/nix_instantid_ipadapter/pytorch/default/1/INSTANTID_ip-adapter.bin ./models/ipadapter/INSTANTID_ip-adapter.bin

# %%
start_playit_agent()

# %%
# %ls -lha ./models/instantid

# %%
# !ps fax

# %%
# !uv  pip install   --system  -q omegaconf accelerate einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !uv pip install  --system -q torch torchvision torchaudio  ultralytics insightface bitsandbytes -U
# !uv pip install  --system -q torchsde -U

# %%
# !tail /kaggle/working/ComfyUI/logs/playit.log

# %%
# %ls -ltrah /kaggle/working/ComfyUI/custom_nodes/ | grep -i subpack

# %%
# %%writefile /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Impact-Subpack/modules/subcore.py
from PIL import Image

import cv2
import numpy as np
import torch
from collections import namedtuple
from . import utils
import inspect
import logging
import os

import pickle
import folder_paths


orig_torch_load = torch.load


SEG = namedtuple("SEG",
                 ['cropped_image', 'cropped_mask', 'confidence', 'crop_region', 'bbox', 'label', 'control_net_wrapper'],
                 defaults=[None])


# --- Whitelist Configuration ---
WHITELIST_DIR = None
WHITELIST_FILE_PATH = None

try:
    # --- Attempting: Use ComfyUI's folder_paths (Preferred Method) ---
    user_dir = folder_paths.get_user_directory()
    if user_dir and os.path.isdir(user_dir):
        WHITELIST_DIR = os.path.join(user_dir, "default", "ComfyUI-Impact-Subpack")
        WHITELIST_FILE_PATH = os.path.join(WHITELIST_DIR, "model-whitelist.txt")
        logging.info(f"[Impact Pack/Subpack] Using folder_paths to determine whitelist path: {WHITELIST_FILE_PATH}")
    else:
        logging.warning(f"[Impact Pack/Subpack] folder_paths.get_user_directory() returned invalid path: {user_dir}.")

    # --- Ensure directory exists---
    if WHITELIST_FILE_PATH: # Check if any method succeeded in setting the path
        try:
            # Crucially, create the DIRECTORY first
            # Use the WHITELIST_DIR determined by one of the methods above
            os.makedirs(WHITELIST_DIR, exist_ok=True)
            logging.info(f"[Impact Pack/Subpack] Ensured whitelist directory exists: {WHITELIST_DIR}")
        except OSError as e:
            logging.error(f"[Impact Pack/Subpack] Failed to create whitelist directory {WHITELIST_DIR}: {e}. Whitelisting may not function.")
            WHITELIST_FILE_PATH = None # Indicate failure / disable whitelisting
        except Exception as e:
            logging.error(f"[Impact Pack/Subpack] Unexpected error creating whitelist directory: {e}", exc_info=True)
            WHITELIST_FILE_PATH = None # Indicate failure / disable whitelisting
    else:
         # Handle case where path determination failed via all methods
         logging.error("[Impact Pack/Subpack] Whitelist path determination failed using all methods. Whitelisting disabled.")
         # WHITELIST_FILE_PATH is already None


except Exception as e:
    # Catch errors during the whole setup process (e.g., inspect failing)
    logging.error(f"[Impact Pack/Subpack] Critical error during whitelist path setup: {e}", exc_info=True)
    WHITELIST_FILE_PATH = None # Disable whitelisting on critical setup error
    logging.error("[Impact Pack/Subpack] Whitelisting disabled due to critical setup error.")


def load_whitelist(filepath):
    """
    Loads filenames from the whitelist file.
    Attempts to create the file with instructions if it doesn't exist.
    Returns a set of approved base filenames.
    """
    approved_files = set()
    # Check again if filepath is valid before proceeding
    if filepath is None or not isinstance(filepath, str):
        # Log was already done if None during setup, avoid duplicate messages
        # logging.error("[Impact Pack/Subpack] Whitelist file path is invalid. Whitelisting disabled.")
        return approved_files # Return empty set

    try:
        # Try reading the existing file
        with open(filepath, 'r') as f:
            for line in f:
                line = line.strip()
                # Store only the base filename for easier matching
                if line and not line.startswith('#'):
                    approved_files.add(os.path.basename(line))
        logging.info(f"[Impact Pack/Subpack] Loaded {len(approved_files)} model(s) from whitelist: {filepath}")

    except FileNotFoundError:
        # This block now runs only if the directory was created successfully but the file is missing
        logging.warning(f"[Impact Pack/Subpack] Model whitelist file not found at: {filepath}. ")
        logging.warning(f" >> An empty whitelist file will be created.")
        logging.warning(f" >> To allow unsafe loading for specific trusted legacy models (e.g., older .pt),")
        logging.warning(f" >> add their base filenames (one per line) to this file.")
        try:
            # Attempt to create the file with comments since it wasn't found
            # This should now succeed because os.makedirs created the directory
            with open(filepath, 'w') as f:
                f.write("# Add base filenames of trusted models (e.g., my_old_yolo.pt) here, one per line.\n")
                f.write("# This allows loading them with `weights_only=False` if they fail safe loading\n")
                f.write("# due to errors like 'restricted getattr' in newer PyTorch versions.\n")
                f.write("# WARNING: Only add files you absolutely trust, as this bypasses a security feature.\n")
                f.write("# Prefer using .safetensors files whenever possible.\n")
            logging.info(f"[Impact Pack/Subpack] Created empty whitelist file: {filepath}")
        except Exception as create_e:
             # Log error if creating the file fails even after creating the directory
             logging.error(f"[Impact Pack/Subpack] Failed to create empty whitelist file at {filepath}: {create_e}", exc_info=True)

    except Exception as e:
        logging.error(f"[Impact Pack/Subpack] Error loading model whitelist from {filepath}: {e}", exc_info=True)

    return approved_files

# Now call the function using the dynamically determined (or None) path
_MODEL_WHITELIST = load_whitelist(WHITELIST_FILE_PATH)

# ---------- End of Whitelist Management ----------

class NO_BBOX_DETECTOR:
    pass


class NO_SEGM_DETECTOR:
    pass


def create_segmasks(results):
    bboxs = results[1]
    segms = results[2]
    confidence = results[3]

    results = []
    for i in range(len(segms)):
        item = (bboxs[i], segms[i].astype(np.float32), confidence[i])
        results.append(item)
    return results


# Limit the commands that can be executed through `getattr` to `ultralytics.nn.modules.head.Detect.forward`.
def restricted_getattr(obj, name, *args):
    if name != "forward":
        logging.error(f"Access to potentially dangerous attribute '{obj.__module__}.{obj.__name__}.{name}' is blocked.\nIf you believe the use of this code is genuinely safe, please report it.\nhttps://github.com/ltdrdata/ComfyUI-Impact-Subpack/issues")
        raise RuntimeError(f"Access to potentially dangerous attribute '{obj.__module__}.{obj.__name__}.{name}' is blocked.")
        
    return getattr(obj, name, *args)

restricted_getattr.__module__ = 'builtins'
restricted_getattr.__name__ = 'getattr'


try:
    from ultralytics import YOLO
    from ultralytics.nn.tasks import DetectionModel
    from ultralytics.nn.tasks import SegmentationModel
    from ultralytics.utils import IterableSimpleNamespace
    from ultralytics.utils.tal import TaskAlignedAssigner
    import ultralytics.nn.modules as modules
    import ultralytics.nn.modules.block as block_modules
    import torch.nn.modules as torch_modules
    import ultralytics.utils.loss as loss_modules
    import dill._dill
    from numpy.core.multiarray import scalar
    try:
        from numpy import dtype
        from numpy.dtypes import Float64DType
    except:
        logging.error("[Impact Subpack] installed 'numpy' is outdated. Please update 'numpy' to 1.26.4")
        raise Exception("[Impact Subpack] installed 'numpy' is outdated. Please update 'numpy' to 1.26.4")


    torch_whitelist = []

    # https://github.com/comfyanonymous/ComfyUI/issues/5516#issuecomment-2466152838
    def build_torch_whitelist():
        """
        For security, only a limited set of namespaces is allowed during loading.

        Since the same module may be identified by different namespaces depending on the model,
        some modules are additionally registered with aliases to ensure backward compatibility.
        """
        global torch_whitelist

        for name, obj in inspect.getmembers(modules):
            if inspect.isclass(obj) and obj.__module__.startswith("ultralytics.nn.modules"):
                aliasObj = type(name, (obj,), {})
                aliasObj.__module__ = "ultralytics.nn.modules"

                torch_whitelist.append(obj)
                torch_whitelist.append(aliasObj)

        for name, obj in inspect.getmembers(block_modules):
            if inspect.isclass(obj) and obj.__module__.startswith("ultralytics.nn.modules"):
                aliasObj = type(name, (obj,), {})
                aliasObj.__module__ = "ultralytics.nn.modules.block"

                torch_whitelist.append(obj)
                torch_whitelist.append(aliasObj)

        for name, obj in inspect.getmembers(loss_modules):
            if inspect.isclass(obj) and obj.__module__.startswith("ultralytics.utils.loss"):
                aliasObj = type(name, (obj,), {})
                aliasObj.__module__ = "ultralytics.yolo.utils.loss"

                torch_whitelist.append(obj)
                torch_whitelist.append(aliasObj)

        for name, obj in inspect.getmembers(torch_modules):
            if inspect.isclass(obj) and obj.__module__.startswith("torch.nn.modules"):
                torch_whitelist.append(obj)

        aliasIterableSimpleNamespace = type("IterableSimpleNamespace", (IterableSimpleNamespace,), {})
        aliasIterableSimpleNamespace.__module__ = "ultralytics.yolo.utils"

        aliasTaskAlignedAssigner = type("TaskAlignedAssigner", (TaskAlignedAssigner,), {})
        aliasTaskAlignedAssigner.__module__ = "ultralytics.yolo.utils.tal"

        aliasYOLOv10DetectionModel = type("YOLOv10DetectionModel", (DetectionModel,), {})
        aliasYOLOv10DetectionModel.__module__ = "ultralytics.nn.tasks"
        aliasYOLOv10DetectionModel.__name__ = "YOLOv10DetectionModel"

        aliasv10DetectLoss = type("v10DetectLoss", (loss_modules.E2EDetectLoss,), {})
        aliasv10DetectLoss.__name__ = "v10DetectLoss"
        aliasv10DetectLoss.__module__ = "ultralytics.utils.loss"

        torch_whitelist += [DetectionModel, aliasYOLOv10DetectionModel, SegmentationModel, IterableSimpleNamespace,
                            aliasIterableSimpleNamespace, TaskAlignedAssigner, aliasTaskAlignedAssigner, aliasv10DetectLoss,
                            restricted_getattr, dill._dill._load_type, scalar, dtype, Float64DType]

    build_torch_whitelist()

except Exception as e:
    logging.error(e)
    logging.error("\n!!!!!\n\n[ComfyUI-Impact-Subpack] If this error occurs, please check the following link:\n\thttps://github.com/ltdrdata/ComfyUI-Impact-Pack/blob/Main/troubleshooting/TROUBLESHOOTING.md\n\n!!!!!\n")
    raise e

# HOTFIX: https://github.com/ltdrdata/ComfyUI-Impact-Pack/issues/754
# importing YOLO breaking original torch.load capabilities

# --- Start: REPLACE the existing torch_wrapper function ---

def torch_wrapper(*args, **kwargs):
    """
    Wrapper for torch.load that attempts safe loading (weights_only=True) first.
    If a specific UnpicklingError related to disallowed globals (like 'getattr')
    occurs, it checks a user-defined whitelist (_MODEL_WHITELIST). If the file
    is whitelisted, it retries with weights_only=False. Otherwise, it blocks
    the unsafe load and raises the error.
    """
    # Use the globally saved original torch.load reference from the top of the file
    # Check if weights_only was explicitly passed by the caller
    # Explicitly declare modification of global scope is intended
    global _MODEL_WHITELIST
    weights_only_explicit = kwargs.get('weights_only', None) # Read value without popping yet

    # Try to get the filename being loaded (usually the first arg if it's a path)
    filename = None
    filename_arg_source = "[unknown source]"
    if args and isinstance(args[0], str):
        filename = os.path.basename(args[0]) # Get just the filename part
        filename_arg_source = args[0]
    elif 'f' in kwargs and isinstance(kwargs['f'], str):
        filename = os.path.basename(kwargs['f']) # Get just the filename part
        filename_arg_source = kwargs['f']
    # Note: filename might remain None if loading from a file-like object

    # Check if using newer PyTorch with safe_globals attribute (indicates >= 2.6 behavior likely)
    if hasattr(torch.serialization, 'safe_globals'):

        # Determine the effective weights_only setting for the FIRST attempt
        load_kwargs = kwargs.copy()
        load_kwargs['weights_only'] = False # ALWAYS attempt safe load first on newer PyTorch

        try:
            # --- Attempt 1: Safe Load ---
            # Try loading with the determined weights_only setting (usually True)
            logging.debug(f"[Impact Pack/Subpack] Attempting safe load (weights_only=True) for: {filename_arg_source}")
            return orig_torch_load(*args, **load_kwargs)

        except pickle.UnpicklingError as e:
            # --- Handle Specific Load Failure ---
            # Check if the error is the specific one caused by disallowed globals
            # like 'getattr' AND we were attempting a safe load (weights_only=True)
            # Using 'getattr' because it was the specific error reported.
            is_disallowed_global_error = 'getattr' in str(e)

            if is_disallowed_global_error:
                # Check the whitelist
                if filename and filename in _MODEL_WHITELIST:
                    # --- Fallback: Whitelisted Unsafe Load ---
                    logging.warning("##############################################################################")
                    logging.warning(f"[Impact Pack/Subpack] WARNING: Safe load failed for '{filename}' (Reason: {e}).")
                    logging.warning(f" >> FILE IS IN THE WHITELIST: {WHITELIST_FILE_PATH}")
                    logging.warning(" >> This model likely uses legacy Python features blocked by default for security.")
                    logging.warning(" >> RETRYING WITH 'weights_only=False' because it's whitelisted.")
                    logging.warning(" >> SECURITY RISK: Ensure you added this file to the whitelist consciously")
                    logging.warning(f" >> and trust its source: {filename_arg_source}")
                    logging.warning(" >> Prefer using .safetensors files whenever available.")
                    logging.warning("##############################################################################")

                    retry_kwargs = kwargs.copy()
                    retry_kwargs['weights_only'] = False
                    # Call the original function again, now unsafely (because whitelisted)
                    return orig_torch_load(*args, **retry_kwargs)

                else:
                    # --- File not in current whitelist, try reloading ---
                    logging.warning(f"[Impact Pack/Subpack] File '{filename}' not found in current whitelist cache.")
                    whitelist_path_msg = WHITELIST_FILE_PATH if WHITELIST_FILE_PATH else "[Path not determined]"
                    logging.info(f"[Impact Pack/Subpack] Attempting to reload whitelist from: {whitelist_path_msg}")
                    try:
                        # Reload the whitelist from the file
                        _MODEL_WHITELIST = load_whitelist(WHITELIST_FILE_PATH)
                        logging.info(f"[Impact Pack/Subpack] Whitelist reloaded. Now contains {len(_MODEL_WHITELIST)} entries.")

                        # --- Re-check Whitelist After Reload ---
                        if filename and filename in _MODEL_WHITELIST:
                            logging.warning("##############################################################################")
                            logging.warning(f"[Impact Pack/Subpack] SUCCESS: File '{filename}' FOUND in reloaded whitelist.")
                            logging.warning(f" >> Proceeding with whitelisted unsafe load (weights_only=False).")
                            logging.warning(f" >> Ensure you recently added this file to: {whitelist_path_msg}")
                            logging.warning(" >> SECURITY RISK: Ensure you trust its source.")
                            logging.warning("##############################################################################")
                            retry_kwargs = kwargs.copy()
                            retry_kwargs['weights_only'] = False
                            return orig_torch_load(*args, **retry_kwargs)
                        else:
                             # File still not found after reload, proceed with blocking
                             logging.error("[Impact Pack/Subpack] File still not found in whitelist after reload.")
                             # Fall through to the original blocking logic below

                    except Exception as reload_e:
                        logging.error(f"[Impact Pack/Subpack] Error occurred during whitelist reload attempt: {reload_e}", exc_info=True)
                        # Fall through to the original blocking logic below if reload fails

                    # --- Blocked: Not Whitelisted (Original Logic - runs if reload failed or file still not found) ---
                    logging.error("##############################################################################")
                    logging.error(f"[Impact Pack/Subpack] ERROR: Safe load failed for '{filename_arg_source}' (Reason: {e}).")
                    logging.error(f" >> This model likely uses legacy Python features blocked by default for security.")
                    # Updated log message here:
                    logging.error(f" >> UNSAFE LOAD BLOCKED because the file ('{filename or 'unknown'}') is NOT in the whitelist (even after reload attempt).")
                    logging.error(f" >> Whitelist path: {whitelist_path_msg}")
                    if filename:
                         logging.error(f" >> To allow loading this specific file (IF YOU TRUST IT), ensure its base name")
                         logging.error(f" >> ('{filename}') is correctly added to the whitelist file (one name per line) and saved.")
                    else:
                         logging.error(f" >> Cannot determine filename to check against whitelist.")
                    logging.error(" >> SECURITY RISK: Only whitelist files from sources you absolutely trust.")
                    logging.error(" >> Prefer using .safetensors files whenever available.")
                    logging.error("##############################################################################")
                    raise e # Re-raise the original security-related error

            else:
                # If it's a different UnpicklingError, re-raise it. Don't attempt unsafe load.
                logging.error(f"[Impact Pack/Subpack] UnpicklingError during safe load (not 'getattr' related): {e}. Re-raising.")
                raise e # Re-raise other UnpicklingErrors

    else:
        # --- Handle Older PyTorch Versions (no safe_globals) ---
        # Behavior here respects the caller's explicit request or defaults to False
        load_kwargs = kwargs.copy()
        effective_weights_only = weights_only_explicit if weights_only_explicit is not None else False # Default False for old torch
        load_kwargs['weights_only'] = effective_weights_only

        if not effective_weights_only:
            logging.warning(f"[Impact Pack/Subpack] Older PyTorch version detected. Proceeding with potentially unsafe load (weights_only=False) for: {filename_arg_source}")
        else:
             logging.debug(f"[Impact Pack/Subpack] Older PyTorch version detected. Proceeding with explicit weights_only=True for: {filename_arg_source}")

        # Call the original torch.load directly with the determined settings for older PyTorch
        return orig_torch_load(*args, **load_kwargs)

# --- End: Replacement block for the torch_wrapper function ---

torch.load = torch_wrapper


def load_yolo(model_path: str):
    # https://github.com/comfyanonymous/ComfyUI/issues/5516#issuecomment-2466152838
    if hasattr(torch.serialization, 'safe_globals'):
        with torch.serialization.safe_globals(torch_whitelist):
            try:
                return YOLO(model_path)
            except ModuleNotFoundError:
                # https://github.com/ultralytics/ultralytics/issues/3856
                YOLO("yolov8n.pt")
                return YOLO(model_path)
    else:
        try:
            return YOLO(model_path)
        except ModuleNotFoundError:
            YOLO("yolov8n.pt")
            return YOLO(model_path)


def inference_bbox(
    model,
    image: Image.Image,
    confidence: float = 0.3,
    device: str = "",
):
    pred = model(image, conf=confidence, device=device)

    bboxes = pred[0].boxes.xyxy.cpu().numpy()
    cv2_image = np.array(image)
    if len(cv2_image.shape) == 3:
        cv2_image = cv2_image[:, :, ::-1].copy()  # Convert RGB to BGR for cv2 processing
    else:
        # Handle the grayscale image here
        # For example, you might want to convert it to a 3-channel grayscale image for consistency:
        cv2_image = cv2.cvtColor(cv2_image, cv2.COLOR_GRAY2BGR)
    cv2_gray = cv2.cvtColor(cv2_image, cv2.COLOR_BGR2GRAY)

    segms = []
    for x0, y0, x1, y1 in bboxes:
        cv2_mask = np.zeros(cv2_gray.shape, np.uint8)
        cv2.rectangle(cv2_mask, (int(x0), int(y0)), (int(x1), int(y1)), 255, -1)
        cv2_mask_bool = cv2_mask.astype(bool)
        segms.append(cv2_mask_bool)

    n, m = bboxes.shape
    if n == 0:
        return [[], [], [], []]

    results = [[], [], [], []]
    for i in range(len(bboxes)):
        results[0].append(pred[0].names[int(pred[0].boxes[i].cls.item())])
        results[1].append(bboxes[i])
        results[2].append(segms[i])
        results[3].append(pred[0].boxes[i].conf.cpu().numpy())

    return results


def inference_segm(
    model,
    image: Image.Image,
    confidence: float = 0.3,
    device: str = "",
):
    pred = model(image, conf=confidence, device=device)

    bboxes = pred[0].boxes.xyxy.cpu().numpy()
    n, m = bboxes.shape
    if n == 0:
        return [[], [], [], []]

    # NOTE: masks.data will be None when n == 0
    segms = pred[0].masks.data.cpu().numpy()

    h_segms = segms.shape[1]
    w_segms = segms.shape[2]
    h_orig = image.size[1]
    w_orig = image.size[0]
    ratio_segms = h_segms / w_segms
    ratio_orig = h_orig / w_orig

    if ratio_segms == ratio_orig:
        h_gap = 0
        w_gap = 0
    elif ratio_segms > ratio_orig:
        h_gap = int((ratio_segms - ratio_orig) * h_segms)
        w_gap = 0
    else:
        h_gap = 0
        ratio_segms = w_segms / h_segms
        ratio_orig = w_orig / h_orig
        w_gap = int((ratio_segms - ratio_orig) * w_segms)

    results = [[], [], [], []]
    for i in range(len(bboxes)):
        results[0].append(pred[0].names[int(pred[0].boxes[i].cls.item())])
        results[1].append(bboxes[i])

        mask = torch.from_numpy(segms[i])
        mask = mask[h_gap:mask.shape[0] - h_gap, w_gap:mask.shape[1] - w_gap]

        scaled_mask = torch.nn.functional.interpolate(mask.unsqueeze(0).unsqueeze(0), size=(image.size[1], image.size[0]),
                                                      mode='bilinear', align_corners=False)
        scaled_mask = scaled_mask.squeeze().squeeze()

        results[2].append(scaled_mask.numpy())
        results[3].append(pred[0].boxes[i].conf.cpu().numpy())

    return results


class UltraBBoxDetector:
    bbox_model = None

    def __init__(self, bbox_model):
        self.bbox_model = bbox_model

    def detect(self, image, threshold, dilation, crop_factor, drop_size=1, detailer_hook=None):
        drop_size = max(drop_size, 1)
        detected_results = inference_bbox(self.bbox_model, utils.tensor2pil(image), threshold)
        segmasks = create_segmasks(detected_results)

        if dilation > 0:
            segmasks = utils.dilate_masks(segmasks, dilation)

        items = []
        h = image.shape[1]
        w = image.shape[2]

        for x, label in zip(segmasks, detected_results[0]):
            item_bbox = x[0]
            item_mask = x[1]

            y1, x1, y2, x2 = item_bbox

            if x2 - x1 > drop_size and y2 - y1 > drop_size:  # minimum dimension must be (2,2) to avoid squeeze issue
                crop_region = utils.make_crop_region(w, h, item_bbox, crop_factor)

                if detailer_hook is not None:
                    crop_region = detailer_hook.post_crop_region(w, h, item_bbox, crop_region)

                cropped_image = utils.crop_image(image, crop_region)
                cropped_mask = utils.crop_ndarray2(item_mask, crop_region)
                confidence = x[2]
                # bbox_size = (item_bbox[2]-item_bbox[0],item_bbox[3]-item_bbox[1]) # (w,h)

                item = SEG(cropped_image, cropped_mask, confidence, crop_region, item_bbox, label, None)

                items.append(item)

        shape = image.shape[1], image.shape[2]
        segs = shape, items

        if detailer_hook is not None and hasattr(detailer_hook, "post_detection"):
            segs = detailer_hook.post_detection(segs)

        return segs

    def detect_combined(self, image, threshold, dilation):
        detected_results = inference_bbox(self.bbox_model, utils.tensor2pil(image), threshold)
        segmasks = create_segmasks(detected_results)
        if dilation > 0:
            segmasks = utils.dilate_masks(segmasks, dilation)

        return utils.combine_masks(segmasks)

    def setAux(self, x):
        pass


class UltraSegmDetector:
    bbox_model = None

    def __init__(self, bbox_model):
        self.bbox_model = bbox_model

    def detect(self, image, threshold, dilation, crop_factor, drop_size=1, detailer_hook=None):
        drop_size = max(drop_size, 1)
        detected_results = inference_segm(self.bbox_model, utils.tensor2pil(image), threshold)
        segmasks = create_segmasks(detected_results)

        if dilation > 0:
            segmasks = utils.dilate_masks(segmasks, dilation)

        items = []
        h = image.shape[1]
        w = image.shape[2]

        for x, label in zip(segmasks, detected_results[0]):
            item_bbox = x[0]
            item_mask = x[1]

            y1, x1, y2, x2 = item_bbox

            if x2 - x1 > drop_size and y2 - y1 > drop_size:  # minimum dimension must be (2,2) to avoid squeeze issue
                crop_region = utils.make_crop_region(w, h, item_bbox, crop_factor)

                if detailer_hook is not None:
                    crop_region = detailer_hook.post_crop_region(w, h, item_bbox, crop_region)

                cropped_image = utils.crop_image(image, crop_region)
                cropped_mask = utils.crop_ndarray2(item_mask, crop_region)
                confidence = x[2]
                # bbox_size = (item_bbox[2]-item_bbox[0],item_bbox[3]-item_bbox[1]) # (w,h)

                item = SEG(cropped_image, cropped_mask, confidence, crop_region, item_bbox, label, None)

                items.append(item)

        shape = image.shape[1], image.shape[2]
        segs = shape, items

        if detailer_hook is not None and hasattr(detailer_hook, "post_detection"):
            segs = detailer_hook.post_detection(segs)

        return segs

    def detect_combined(self, image, threshold, dilation):
        detected_results = inference_segm(self.bbox_model, utils.tensor2pil(image), threshold)
        segmasks = create_segmasks(detected_results)
        if dilation > 0:
            segmasks = utils.dilate_masks(segmasks, dilation)

        return utils.combine_masks(segmasks)

    def setAux(self, x):
        pass

# %%
# !tail /kaggle/working/ComfyUI/logs/playit.log

# %%
! /kaggle/working/ComfyUI/playit-linux-amd64 reset

# %%
start_playit_agent()

# %%
install_packages_list()

# %%
# %ls  -lh /kaggle/working/ComfyUI

# %%
os.makedirs("/kaggle/working/ComfyUI/output")

# %%
install_packages_list()

# %% [raw]
# !kill 5333 4205

# %%
??main

# %%
start_comfyui_instances()

# %%
subprocess.Popen([sys.executable, "main.py", "--cuda-device", "0", "--port", "8188","--highvram", "--fp8_e4m3fn-text-enc","--fp8_e4m3fn-unet"])

# %%
# !uv pip install -U --system pip

# %%
    packages = [
        "https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4",
        "https://github.com/WASasquatch/was-node-suite-comfyui",
        "https://github.com/rgthree/rgthree-comfy",
        "https://codeberg.org/Gourieff/comfyui-reactor-node",
        "https://github.com/BlenderNeko/ComfyUI_Noise",
        "https://github.com/ltdrdata/ComfyUI-Impact-Pack",
        "https://github.com/ltdrdata/ComfyUI-Impact-Subpack",
        
        "https://github.com/yolain/ComfyUI-Easy-Use",
        "https://github.com/kijai/ComfyUI-KJNodes",
        "https://github.com/kijai/ComfyUI-Florence2",
        "https://github.com/XLabs-AI/x-flux-comfyui",
        "https://github.com/crystian/ComfyUI-Crystools",
        "https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes",
        "https://github.com/city96/ComfyUI-GGUF",
        "https://github.com/cubiq/PuLID_ComfyUI",
        "https://github.com/cubiq/ComfyUI_InstantID",
        "https://github.com/cubiq/ComfyUI_IPAdapter_plus",
        "https://github.com/comfyanonymous/ComfyUI_experiments",
        "https://github.com/chengzeyi/Comfy-WaveSpeed",
        "https://github.com/Fannovel16/comfyui_controlnet_aux",
        "https://github.com/ShmuelRonen/ComfyUI-FreeMemory",
        "https://github.com/jamesWalker55/comfyui-various",
        "https://github.com/kijai/ComfyUI-SUPIR",
        "https://github.com/klinter007/klinter_nodes",
        "https://github.com/holchan/ComfyUI-ModelDownloader",
        "https://github.com/KoreTeknology/ComfyUI-Universal-Styler",
        "https://github.com/marduk191/ComfyUI-Fluxpromptenhancer",
        "https://github.com/fairy-root/Flux-Prompt-Generator",
        "https://github.com/VykosX/ControlFlowUtils",
        "https://github.com/godmt/ComfyUI-List-Utils",
        "https://github.com/pythongosssss/ComfyUI-WD14-Tagger",
        "https://github.com/miaoshouai/ComfyUI-Miaoshouai-Tagger",
        "https://github.com/GraftingRayman/ComfyUI_GraftingRayman",
        "https://github.com/pollockjj/ComfyUI-MultiGPU",
        "https://github.com/dchatel/comfyui_facetools",
        "https://github.com/fssorc/ComfyUI_FaceShaper",
        
        "https://github.com/vuongminh1907/ComfyUI_ZenID",
        "https://github.com/nuanarchy/ComfyUI-NuA-FlashFace",
        "https://github.com/nosiu/comfyui-instantId-faceswap",
        "https://github.com/EnragedAntelope/ComfyUI-EACloudNodes",
        "https://github.com/nicofdga/DZ-FaceDetailer",
        "https://github.com/mav-rik/facerestore_cf",
        "https://github.com/smthemex/ComfyUI_InstantIR_Wrapper",
        "https://github.com/cubiq/ComfyUI_essentials",

        
        "https://github.com/Kosinkadink/ComfyUI-Advanced-ControlNet",
        "https://github.com/EvilBT/ComfyUI_SLK_joy_caption_two",
        "https://github.com/PowerHouseMan/ComfyUI-AdvancedLivePortrait",
        "https://github.com/ssitu/ComfyUI_UltimateSDUpscale",
        "https://github.com/kijai/ComfyUI-CCSR",
        "https://github.com/TheBill2001/comfyui-upscale-by-model",
        "https://github.com/zentrocdot/ComfyUI-RealESRGAN_Upscaler",
        "https://github.com/traugdor/ComfyUI-UltimateSDUpscale-GGUF",
        "https://github.com/jags111/efficiency-nodes-comfyui",
        "https://github.com/kijai/ComfyUI-segment-anything-2",
        "https://github.com/Extraltodeus/ComfyUI-AutomaticCFG",
        "https://github.com/ltdrdata/ComfyUI-Inspire-Pack",
        "https://github.com/evanspearman/ComfyMath",
        "https://github.com/Derfuu/Derfuu_ComfyUI_ModdedNodes",
        "https://github.com/storyicon/comfyui_segment_anything",
        

        "https://github.com/zhangp365/ComfyUI-utils-nodes",
        "https://github.com/pythongosssss/ComfyUI-Custom-Scripts",
        "https://github.com/revirevy/Comfyui_saveimage_imgbb",
        "https://github.com/ltdrdata/ComfyUI-Manager",
        
        ]
    for package in packages:
        install_package(package)

# %%
# !ps fax

# %%
# start_comfyui_instances()
start_playit_agent()

# %%
# !kill 1592

# %% [raw]
# start_comfyui_instances()

# %% [raw]
# %rm -r /kaggle/working/ComfyUI

# %%
# %rm -r /kaggle/working/ComfyUI/output* /kaggle/working/old_output* /kaggle/working/ComfyUI/output*

# %% [raw]
# !kill 1493 1510 1541

# %%
# !du -h /kaggle/working/ComfyUI/models/flashface/* --max-depth=1

# %%
# !rm /kaggle/working/ComfyUI/models/clip_vision/clip_vision_g.safetensors

# %%
# %ls -ltrha /kaggle/working/ComfyUI/models/clip_vision

# %% [raw]
# xlist = """https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/reswapper_256.onnx?download=true
# https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/reswapper_128.onnx?download=true
# https://huggingface.co/datasets/Gourieff/ReActor/resolve/main/models/inswapper_128.onnx?download=true""".split('\n')
#
# os.makedirs("/kaggle/working/ComfyUI/models/reswapper/")
#
# for x in xlist:
#     print(x)
#     filnm = x.split('/')[-1].replace('?download=true','')
#     print(filnm)
#     !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M $x -d /kaggle/working/ComfyUI/models/reswapper/ -o $filnm

# %%
dir()

# %%
# !tail -n 100 /kaggle/working/ComfyUI/logs/playit.log

# %%
    scheduler_thread = threading.Thread(target=scheduler)
    scheduler_thread.daemon = True
    scheduler_thread.start()

# %% [raw]
# !ps fax

# %% [raw]
# # %load main.py
# import comfy.options
# comfy.options.enable_args_parsing()
#
# import os
# import importlib.util
# import folder_paths
# import time
# from comfy.cli_args import args
# from app.logger import setup_logger
# import itertools
# import utils.extra_config
# import logging
#
# if __name__ == "__main__":
#     #NOTE: These do not do anything on core ComfyUI which should already have no communication with the internet, they are for custom nodes.
#     os.environ['HF_HUB_DISABLE_TELEMETRY'] = '1'
#     os.environ['DO_NOT_TRACK'] = '1'
#
#
# setup_logger(log_level=args.verbose, use_stdout=args.log_stdout)
#
# def apply_custom_paths():
#     # extra model paths
#     extra_model_paths_config_path = os.path.join(os.path.dirname(os.path.realpath(__file__)), "extra_model_paths.yaml")
#     if os.path.isfile(extra_model_paths_config_path):
#         utils.extra_config.load_extra_path_config(extra_model_paths_config_path)
#
#     if args.extra_model_paths_config:
#         for config_path in itertools.chain(*args.extra_model_paths_config):
#             utils.extra_config.load_extra_path_config(config_path)
#
#     # --output-directory, --input-directory, --user-directory
#     if args.output_directory:
#         output_dir = os.path.abspath(args.output_directory)
#         logging.info(f"Setting output directory to: {output_dir}")
#         folder_paths.set_output_directory(output_dir)
#
#     # These are the default folders that checkpoints, clip and vae models will be saved to when using CheckpointSave, etc.. nodes
#     folder_paths.add_model_folder_path("checkpoints", os.path.join(folder_paths.get_output_directory(), "checkpoints"))
#     folder_paths.add_model_folder_path("clip", os.path.join(folder_paths.get_output_directory(), "clip"))
#     folder_paths.add_model_folder_path("vae", os.path.join(folder_paths.get_output_directory(), "vae"))
#     folder_paths.add_model_folder_path("diffusion_models",
#                                        os.path.join(folder_paths.get_output_directory(), "diffusion_models"))
#     folder_paths.add_model_folder_path("loras", os.path.join(folder_paths.get_output_directory(), "loras"))
#
#     if args.input_directory:
#         input_dir = os.path.abspath(args.input_directory)
#         logging.info(f"Setting input directory to: {input_dir}")
#         folder_paths.set_input_directory(input_dir)
#
#     if args.user_directory:
#         user_dir = os.path.abspath(args.user_directory)
#         logging.info(f"Setting user directory to: {user_dir}")
#         folder_paths.set_user_directory(user_dir)
#
#
# def execute_prestartup_script():
#     def execute_script(script_path):
#         module_name = os.path.splitext(script_path)[0]
#         try:
#             spec = importlib.util.spec_from_file_location(module_name, script_path)
#             module = importlib.util.module_from_spec(spec)
#             spec.loader.exec_module(module)
#             return True
#         except Exception as e:
#             logging.error(f"Failed to execute startup-script: {script_path} / {e}")
#         return False
#
#     if args.disable_all_custom_nodes:
#         return
#
#     node_paths = folder_paths.get_folder_paths("custom_nodes")
#     for custom_node_path in node_paths:
#         possible_modules = os.listdir(custom_node_path)
#         node_prestartup_times = []
#
#         for possible_module in possible_modules:
#             module_path = os.path.join(custom_node_path, possible_module)
#             if os.path.isfile(module_path) or module_path.endswith(".disabled") or module_path == "__pycache__":
#                 continue
#
#             script_path = os.path.join(module_path, "prestartup_script.py")
#             if os.path.exists(script_path):
#                 time_before = time.perf_counter()
#                 success = execute_script(script_path)
#                 node_prestartup_times.append((time.perf_counter() - time_before, module_path, success))
#     if len(node_prestartup_times) > 0:
#         logging.info("\nPrestartup times for custom nodes:")
#         for n in sorted(node_prestartup_times):
#             if n[2]:
#                 import_message = ""
#             else:
#                 import_message = " (PRESTARTUP FAILED)"
#             logging.info("{:6.1f} seconds{}: {}".format(n[0], import_message, n[1]))
#         logging.info("")
#
# apply_custom_paths()
# execute_prestartup_script()
#
#
# # Main code
# import asyncio
# import shutil
# import threading
# import gc
#
#
# if os.name == "nt":
#     logging.getLogger("xformers").addFilter(lambda record: 'A matching Triton is not available' not in record.getMessage())
#
# if __name__ == "__main__":
#     if args.cuda_device is not None:
#         os.environ['CUDA_VISIBLE_DEVICES'] = str(args.cuda_device)
#         os.environ['HIP_VISIBLE_DEVICES'] = str(args.cuda_device)
#         logging.info("Set cuda device to: {}".format(args.cuda_device))
#
#     if args.oneapi_device_selector is not None:
#         os.environ['ONEAPI_DEVICE_SELECTOR'] = args.oneapi_device_selector
#         logging.info("Set oneapi device selector to: {}".format(args.oneapi_device_selector))
#
#     if args.deterministic:
#         if 'CUBLAS_WORKSPACE_CONFIG' not in os.environ:
#             os.environ['CUBLAS_WORKSPACE_CONFIG'] = ":4096:8"
#
#     import cuda_malloc
#
# if args.windows_standalone_build:
#     try:
#         from fix_torch import fix_pytorch_libomp
#         fix_pytorch_libomp()
#     except:
#         pass
#
# import comfy.utils
#
# import execution
# import server
# from server import BinaryEventTypes
# import nodes
# import comfy.model_management
# import comfyui_version
#
#
# def cuda_malloc_warning():
#     device = comfy.model_management.get_torch_device()
#     device_name = comfy.model_management.get_torch_device_name(device)
#     cuda_malloc_warning = False
#     if "cudaMallocAsync" in device_name:
#         for b in cuda_malloc.blacklist:
#             if b in device_name:
#                 cuda_malloc_warning = True
#         if cuda_malloc_warning:
#             logging.warning("\nWARNING: this card most likely does not support cuda-malloc, if you get \"CUDA error\" please run ComfyUI with: --disable-cuda-malloc\n")
#
#
# def prompt_worker(q, server_instance):
#     current_time: float = 0.0
#     e = execution.PromptExecutor(server_instance, lru_size=args.cache_lru)
#     last_gc_collect = 0
#     need_gc = False
#     gc_collect_interval = 10.0
#
#     while True:
#         timeout = 1000.0
#         if need_gc:
#             timeout = max(gc_collect_interval - (current_time - last_gc_collect), 0.0)
#
#         queue_item = q.get(timeout=timeout)
#         if queue_item is not None:
#             item, item_id = queue_item
#             execution_start_time = time.perf_counter()
#             prompt_id = item[1]
#             server_instance.last_prompt_id = prompt_id
#
#             e.execute(item[2], prompt_id, item[3], item[4])
#             need_gc = True
#             q.task_done(item_id,
#                         e.history_result,
#                         status=execution.PromptQueue.ExecutionStatus(
#                             status_str='success' if e.success else 'error',
#                             completed=e.success,
#                             messages=e.status_messages))
#             if server_instance.client_id is not None:
#                 server_instance.send_sync("executing", {"node": None, "prompt_id": prompt_id}, server_instance.client_id)
#
#             current_time = time.perf_counter()
#             execution_time = current_time - execution_start_time
#             logging.info("Prompt executed in {:.2f} seconds".format(execution_time))
#
#         flags = q.get_flags()
#         free_memory = flags.get("free_memory", False)
#
#         if flags.get("unload_models", free_memory):
#             comfy.model_management.unload_all_models()
#             need_gc = True
#             last_gc_collect = 0
#
#         if free_memory:
#             e.reset()
#             need_gc = True
#             last_gc_collect = 0
#
#         if need_gc:
#             current_time = time.perf_counter()
#             if (current_time - last_gc_collect) > gc_collect_interval:
#                 gc.collect()
#                 comfy.model_management.soft_empty_cache()
#                 last_gc_collect = current_time
#                 need_gc = False
#
#
# async def run(server_instance, address='', port=8188, verbose=True, call_on_start=None):
#     addresses = []
#     for addr in address.split(","):
#         addresses.append((addr, port))
#     await asyncio.gather(
#         server_instance.start_multi_address(addresses, call_on_start, verbose), server_instance.publish_loop()
#     )
#
#
# def hijack_progress(server_instance):
#     def hook(value, total, preview_image):
#         comfy.model_management.throw_exception_if_processing_interrupted()
#         progress = {"value": value, "max": total, "prompt_id": server_instance.last_prompt_id, "node": server_instance.last_node_id}
#
#         server_instance.send_sync("progress", progress, server_instance.client_id)
#         if preview_image is not None:
#             server_instance.send_sync(BinaryEventTypes.UNENCODED_PREVIEW_IMAGE, preview_image, server_instance.client_id)
#
#     comfy.utils.set_progress_bar_global_hook(hook)
#
#
# def cleanup_temp():
#     temp_dir = folder_paths.get_temp_directory()
#     if os.path.exists(temp_dir):
#         shutil.rmtree(temp_dir, ignore_errors=True)
#
#
# def start_comfyui(asyncio_loop=None):
#     """
#     Starts the ComfyUI server using the provided asyncio event loop or creates a new one.
#     Returns the event loop, server instance, and a function to start the server asynchronously.
#     """
#     if args.temp_directory:
#         temp_dir = os.path.join(os.path.abspath(args.temp_directory), "temp")
#         logging.info(f"Setting temp directory to: {temp_dir}")
#         folder_paths.set_temp_directory(temp_dir)
#     cleanup_temp()
#
#     if args.windows_standalone_build:
#         try:
#             import new_updater
#             new_updater.update_windows_updater()
#         except:
#             pass
#
#     if not asyncio_loop:
#         asyncio_loop = asyncio.new_event_loop()
#         asyncio.set_event_loop(asyncio_loop)
#     prompt_server = server.PromptServer(asyncio_loop)
#     q = execution.PromptQueue(prompt_server)
#
#     nodes.init_extra_nodes(init_custom_nodes=not args.disable_all_custom_nodes)
#
#     cuda_malloc_warning()
#
#     prompt_server.add_routes()
#     hijack_progress(prompt_server)
#
#     threading.Thread(target=prompt_worker, daemon=True, args=(q, prompt_server,)).start()
#
#     if args.quick_test_for_ci:
#         exit(0)
#
#     os.makedirs(folder_paths.get_temp_directory(), exist_ok=True)
#     call_on_start = None
#     if args.auto_launch:
#         def startup_server(scheme, address, port):
#             import webbrowser
#             if os.name == 'nt' and address == '0.0.0.0':
#                 address = '127.0.0.1'
#             if ':' in address:
#                 address = "[{}]".format(address)
#             webbrowser.open(f"{scheme}://{address}:{port}")
#         call_on_start = startup_server
#
#     async def start_all():
#         await prompt_server.setup()
#         await run(prompt_server, address=args.listen, port=args.port, verbose=not args.dont_print_server, call_on_start=call_on_start)
#
#     # Returning these so that other code can integrate with the ComfyUI loop and server
#     return asyncio_loop, prompt_server, start_all
#
#
# if __name__ == "__main__":
#     # Running directly, just start ComfyUI.
#     logging.info("ComfyUI version: {}".format(comfyui_version.__version__))
#     event_loop, _, start_all_func = start_comfyui()
#     try:
#         event_loop.run_until_complete(start_all_func())
#     except KeyboardInterrupt:
#         logging.info("\nStopped server")
#
#     cleanup_temp()

# %% [raw]
# import os
# import subprocess
# import time
# import zipfile
# import shutil
# from datetime import datetime
# import threading
# from IPython.core.getipython import get_ipython
#
# def zip_folder(folder_path, zip_path):
#     """Zip the contents of a folder."""
#     print("="*60, "Starting to zip folder...", "-"*60, sep="\n")
#     with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
#         for root, _, files in os.walk(folder_path):
#             for file in files:
#                 file_path = os.path.join(root, file)
#                 arcname = os.path.relpath(file_path, folder_path)
#                 zipf.write(file_path, arcname)
#     print("="*60, "Folder zipped successfully.", "-"*60, sep="\n")
#
# def move_files(source_folder, dest_folder):
#     """Move files from source folder to destination folder."""
#     print("="*60, "Starting to move files...", "-"*60, sep="\n")
#     os.makedirs(dest_folder, exist_ok=True)
#     if os.path.exists(source_folder):
#         for item in os.listdir(source_folder):
#             try:
#                 shutil.move(os.path.join(source_folder, item), dest_folder)
#             except Exception as e:
#                 print(f"Error moving file {item}: {e}")
#     print("="*60, "Files moved successfully.", "-"*60, sep="\n")
#
# def install_package(url):
#     """Install a package from a given URL."""
#     print("="*60, f"Starting to install package from {url}...", "-"*60, sep="\n")
#     package_name = url.split('/')[-1].replace('.git', '')
#     package_path = f"/kaggle/working/ComfyUI/custom_nodes/{package_name}"
#
#     if not os.path.exists("/kaggle/working/ComfyUI/custom_nodes/"):
#         os.makedirs("/kaggle/working/ComfyUI/custom_nodes/")
#
#     os.chdir("/kaggle/working/ComfyUI/custom_nodes")
#
#     if not os.path.exists(package_path):
#         get_ipython().system(f'git clone {url} --recursive')
#
#     os.chdir(package_path)
#     get_ipython().system('git pull --all')
#
#     if os.path.exists("requirements.txt"):
#         get_ipython().system('uv pip install --system -r requirements.txt --quiet')
#
#     print("="*60, f"Package from {url} installed successfully.", "-"*60, sep="\n")
#
# def setup_comfyui():
#     """Set up ComfyUI and install necessary packages."""
#     print("="*60, "Starting to set up ComfyUI...", "-"*60, sep="\n")
#     os.chdir("/kaggle/working")
#     if not os.path.exists("/kaggle/working/ComfyUI/") or not os.path.exists("/kaggle/working/ComfyUI/requirements") :
#         get_ipython().system('git clone https://github.com/comfyanonymous/ComfyUI.git --recursive')
#     os.chdir("ComfyUI")
#     get_ipython().system('git pull --all')
#     get_ipython().system('uv pip install --system -r requirements.txt --quiet')
#
#     model_dirs = [
#         "/kaggle/working/ComfyUI/models/LLM",
#         "/kaggle/working/ComfyUI/models/pulid",
#         "/kaggle/working/ComfyUI/models/clip_vision",
#         "/kaggle/working/ComfyUI/models/xlabs/contronets/"
#     ]
#     for dir_path in model_dirs:
#         os.makedirs(dir_path, exist_ok=True)
#     print("="*60, "ComfyUI set up successfully.", "-"*60, sep="\n")
#
# def xlinkthis(src, dest):
#     import os
#     os.makedirs(os.path.dirname(dest), exist_ok=True)
#     if not os.path.exists(dest) and not os.path.islink(dest):
#         os.symlink(src, dest)
#
# def link_models():
#     """Create symbolic links for model files."""
#     print("="*60, "Starting to link models...", "-"*60, sep="\n")
#     links = [
#         ("/kaggle/input/clip-gmp-vit-l-14/tensorflow2/default/1/model.safetensors",
#          "/kaggle/working/ComfyUI/models/clip/CLIP_gmp_VIT_L_14.safetensors"),
#         ("/kaggle/input/t5xxl_fp16.safetensors/tensorflow2/default/1/t5xxl_fp16.safetensors",
#          "/kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors"),
#         ("/kaggle/input/flux-vae-safetensors/pytorch/default/1/ae.safetensors",
#          "/kaggle/working/ComfyUI/models/vae/FLuX_ae.safetensors"),
#         ("/kaggle/input/florence2/transformers/default/1/Florence2_model_3/model.safetensors",
#          "/kaggle/working/ComfyUI/models/LLM/Florence_model_3.safetensors"),
#         ("/kaggle/input/florence2/transformers/default/1/Florence2_model_2/model.safetensors",
#          "/kaggle/working/ComfyUI/models/LLM/Florence_model_2.safetensors"),
#         ("/kaggle/input/controlnet/pytorch/flux-canny-controlnet/1/flux-canny-controlnet-v3.safetensors",
#          "/kaggle/working/ComfyUI/models/xlabs/contronets/flux-canny-controlnet-v3.safetensors"),
#         ("/kaggle/input/controlnet/pytorch/flux-depth-controlnet/1/flux-depth-controlnet-v3.safetensors",
#          "/kaggle/working/ComfyUI/models/xlabs/contronets/flux-depth-controlnet-v3.safetensors"),
#         ("/kaggle/input/realvisxl-v50/pytorch/default/1/realvisxl-v50.safetensors",
#          "/kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50.safetensors"),
#         ("/kaggle/input/realvisxl-v50/pytorch/default/2/SG161222_RealVisXL_V5_0_Lightning.safetensors",
#          "/kaggle/working/ComfyUI/models/checkpoints/SG161222_RealVisXL_V5_0_Lightning.safetensors"),
#         ("/kaggle/input/flux1devnf46stepsnsfw/pytorch/default/1/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors",
#          "/kaggle/working/ComfyUI/models/checkpoints/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors"),
#         ("/kaggle/input/8stepscrearthyperfluxdevbnb_v24hyperdevfp8unet_/pytorch/default/1/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors",
#          "/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors"),
#         ("/kaggle/input/creart-hyper-flux-dev-gguf-q4_0/gguf/default/1/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf",
#          "/kaggle/working/ComfyUI/models/unet/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf"),
#         ("/kaggle/input/unet/gguf/flux1-dev-q4_k_s/1/flux1-dev-Q4_K_S.gguf",
#          "/kaggle/working/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf"),
#         ("/kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors",
#          "/kaggle/working/ComfyUI/models/checkpoints/albedobaseXL_v3Mini.safetensors"),
#         ("/kaggle/input/alimama-flux-turbo-lora/pytorch/default/1/diffusion_pytorch_model.safetensors",
#          "/kaggle/working/ComfyUI/models/loras/alimama-flux-turbo-lora.safetensors"),
#         ("/kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors",
#          "/kaggle/working/ComfyUI/models/checkpoints/fluxArtfusion4Steps_v12.safetensors"),
#         ("/kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin",
#          "/kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin"),
#         ("/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/controlnet_instantid_model.safetensors",
#          "/kaggle/working/ComfyUI/models/controlnet/instantid/LeInstantID_ControlNet_model.safetensors"),
#         ("/kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin",
#          "/kaggle/working/ComfyUI/models/instantid/InstantID_ip_adapter.bin"),
#         ("/kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin",
#          "/kaggle/working/ComfyUI/models/instantid/ip_adapter.bin"),
#         ("/kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin",
#          "/kaggle/working/ComfyUI/models/instantid/SDXL/ip-adapter.bin"),
#         ("/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/controlnet_instantid_model.safetensors",
#          "/kaggle/working/ComfyUI/models/controlnet/instantid/LeInstantID_ControlNet_model.safetensors"),
#         ("/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/4xnomosunidat_upscaler.safetensors",
#          "/kaggle/working/ComfyUI/models/upscale_models/4xnomosunidat_upscaler.safetensors")
#     ]
#     for src, dest in links:
#         xlinkthis(src,dest)
#     print("="*60, "Models linked successfully.", "-"*60, sep="\n")
#
# def link_additional_models():
#     """Link additional models from specified directories."""
#     print("="*60, "Starting to link additional models...", "="*60, sep="\n")
#
#     # Link models from /kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/
#     for x in os.listdir("/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/"):
#         print(x)
#         xlinkthis(f"/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/{x}", f"/kaggle/working/ComfyUI/models/upscale_models/{x}")
#
#     # Link models from /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/
#     for x in os.listdir("/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/"):
#         print(x)
#         xlinkthis(f"/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/{x}", f"/kaggle/working/ComfyUI/models/clip/{x}")
#
#     # Link models from /kaggle/input/sdxl_controlnets/pytorch/default/3/
#     for x in os.listdir("/kaggle/input/sdxl_controlnets/pytorch/default/3/"):
#         print(x)
#         os.symlink(f"/kaggle/input/sdxl_controlnets/pytorch/default/3/{x}", f"/kaggle/working/ComfyUI/models/controlnet/{x}")
#         if 'ip-adapter' in x:
#             xlinkthis(f"/kaggle/input/sdxl_controlnets/pytorch/default/3/{x}", f"/kaggle/working/ComfyUI/models/ipadapter/{x}")
#
#     # Link models from /kaggle/input/pulid-model/pytorch/default/3/
#     for x in os.listdir("/kaggle/input/pulid-model/pytorch/default/3/"):
#         print(x)
#         xlinkthis(f"/kaggle/input/pulid-model/pytorch/default/3/{x}", f"/kaggle/working/ComfyUI/models/pulid/{x}")
#
#     print("="*60, "Additional models linked successfully.", "="*60, sep="\n")
#
# def start_comfyui_instances():
#     """Start ComfyUI instances."""
#     print("="*60, "Starting ComfyUI instances...", "-"*60, sep="\n")
#     os.chdir("/kaggle/working/ComfyUI/")
#     xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188", "--highvram"])
#     time.sleep(10)
#     xP2 = subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189", "--highvram"])
#     time.sleep(10)
#     print("="*60, "ComfyUI instances started successfully.", "-"*60, sep="\n")
#
# def start_playit_agent():
#     """Start the Playit agent."""
#     print("="*60, "Starting Playit agent...", "-"*60, sep="\n")
#     os.chdir("/kaggle/working/ComfyUI/")
#     if not os.path.exists('/kaggle/working/ComfyUI/playit-linux-amd64'):
#         get_ipython().system('wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64')
#     get_ipython().system('chmod +x ./playit-linux-amd64')
#     os.makedirs("/kaggle/working/ComfyUI/logs", exist_ok=True)
#     subprocess.Popen("nohup /kaggle/working/ComfyUI/playit-linux-amd64 >> /kaggle/working/ComfyUI/logs/playit.log 2>&1 &", bufsize=0, shell=True)
#     time.sleep(3)
#     get_ipython().system('tail -n 20 /kaggle/working/ComfyUI/logs/playit.log')
#     print("="*60, "Playit agent started successfully.", "-"*60, sep="\n")
#
# def execute_first_cell():
#     """Execute the first cell in the notebook."""
#     print("="*60, "Executed", datetime.today(), "-"*60, sep="\n")
#     get_ipython().run_cell(get_ipython().user_ns['In'][1])
#     print("="*60, "-"*60, sep="\n")
#
# def scheduler():
#     """Scheduler to execute the first cell every minute."""
#     print("="*60, "Starting scheduler...", "-"*60, sep="\n")
#     while True:
#         execute_first_cell()
#         time.sleep(60)  # 60 seconds
#
# def main():
#     """Main function to orchestrate the setup and execution."""
#     print("="*60, "Starting main function...", "-"*60, sep="\n")
#     # Install uv
#     print("="*60, "Installing uv...", "-"*60, sep="\n")
#     get_ipython().system('python -m pip install -U pip uv -q')
#
#     # Example usage of zip_folder
#     folder_to_zip = '/kaggle/working/ComfyUI/output'
#     if os.path.exists(folder_to_zip):
#         output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
#         zip_folder(folder_to_zip, output_zip)
#
#         # Move files
#         x_old = '/kaggle/working/old_output'
#         move_files(folder_to_zip, x_old)
#
#     # Setup ComfyUI
#     setup_comfyui()
#
#     # Install packages
#     packages = [
#         "https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4",
#         "https://github.com/WASasquatch/was-node-suite-comfyui",
#         "https://github.com/rgthree/rgthree-comfy",
#         "https://codeberg.org/Gourieff/comfyui-reactor-node",
#         "https://github.com/BlenderNeko/ComfyUI_Noise",
#         "https://github.com/ltdrdata/ComfyUI-Impact-Pack",
#         "https://github.com/pythongosssss/ComfyUI-Custom-Scripts",
#         "https://github.com/yolain/ComfyUI-Easy-Use",
#         "https://github.com/kijai/ComfyUI-KJNodes",
#         "https://github.com/kijai/ComfyUI-Florence2",
#         "https://github.com/XLabs-AI/x-flux-comfyui",
#         "https://github.com/crystian/ComfyUI-Crystools",
#         "https://github.com/city96/ComfyUI-GGUF",
#         "https://github.com/cubiq/PuLID_ComfyUI",
#         "https://github.com/cubiq/ComfyUI_InstantID",
#         "https://github.com/cubiq/ComfyUI_IPAdapter_plus",
#         "https://github.com/revirevy/Comfyui_saveimage_imgbb",
#         "https://github.com/ltdrdata/ComfyUI-Manager",
#         "https://github.com/comfyanonymous/ComfyUI_experiments",
#         "https://github.com/chengzeyi/Comfy-WaveSpeed",
#         "https://github.com/Fannovel16/comfyui_controlnet_aux",
#         "https://github.com/ShmuelRonen/ComfyUI-FreeMemory",
#         "https://github.com/jamesWalker55/comfyui-various",
#         "https://github.com/kijai/ComfyUI-SUPIR",
#         "https://github.com/klinter007/klinter_nodes",
#         "https://github.com/holchan/ComfyUI-ModelDownloader",
#         "https://github.com/KoreTeknology/ComfyUI-Universal-Styler",
#         "https://github.com/marduk191/ComfyUI-Fluxpromptenhancer",
#         "https://github.com/fairy-root/Flux-Prompt-Generator",
#         "https://github.com/VykosX/ControlFlowUtils",
#         "https://github.com/godmt/ComfyUI-List-Utils"
#     ]
#     for package in packages:
#         install_package(package)
#
#     # Setup ComfyUI
#     setup_comfyui()
#
#     # Link models
#     link_models()
#
#     # Start ComfyUI instances
#     start_comfyui_instances()
#
#     # Start Playit agent
#     start_playit_agent()
#
#     # Start scheduler
#     scheduler_thread = threading.Thread(target=scheduler)
#     scheduler_thread.daemon = True
#     scheduler_thread.start()
#
#     print("="*60, "Scheduler started in background. It will execute the first cell every 1 minute.", "-"*60, sep="\n")
#
# if __name__ == "__main__":
#     main()

# %% [raw]
# !tail -n 20 /kaggle/working/ComfyUI/logs/playit.log

# %% [raw]
# import os,subprocess,time

# %% [raw]
# %pip install -U uv -q

# %% [raw]
# import os
# from IPython.display import FileLink
# os.chdir("/kaggle/working")
#
# FileLink('output_18112024_1959.zip.zip')

# %% [raw]
# import os
# import zipfile
# from datetime import datetime
#
# def zip_folder(folder_path, zip_path):
#     with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
#         for root, _, files in os.walk(folder_path):
#             for file in files:
#                 file_path = os.path.join(root, file)
#                 arcname = os.path.relpath(file_path, folder_path)
#                 zipf.write(file_path, arcname)
#
# # Example usage
# folder_to_zip = '/kaggle/working/ComfyUI/output'
# output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
# # zip_folder(folder_to_zip, output_zip)
#
# import shutil
# shutil.make_archive(output_zip, 'zip', folder_to_zip)
#
#
# # Example usage
# folder_to_zip = '/kaggle/working/ComfyUI/output'
# output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
# # zip_folder(folder_to_zip, output_zip)
#
# import shutil
# x_old = '/kaggle/working/old_output'
# os.makedirs(x_old,exist_ok=True)
# if os.path.exists(folder_to_zip):
#     for x in os.listdir(folder_to_zip):
#         try:
#             shutil.move(folder_to_zip +'/' + x, x_old)
#         except:
#             print("Fichier deja existant??")

# %% [raw]
# def install_this(xthe_url):
#     import os
#     print("install ",xthe_url)
#     if not os.path.exists("/kaggle/working/ComfyUI/custom_nodes/"):
#         os.makedirs("/kaggle/working/ComfyUI/custom_nodes/")
#
#     %cd /kaggle/working/ComfyUI/custom_nodes
#     xfolder =  xthe_url.split('/')[-1].replace('.git','')
#     if not os.path.exists("/kaggle/working/ComfyUI/custom_nodes/" + xfolder):
#         get_ipython().system(f'git clone {xthe_url} --recursive')
#
#     print(f"{xfolder=}")
#     %cd /kaggle/working/ComfyUI/custom_nodes/$xfolder
#     get_ipython().system('git pull --all')
#     if os.path.exists("requirements.txt"):
#         !uv pip install --system -r requirements.txt --quiet  #-U --upgrade-strategy only-if-needed
# #     else :
# #         %pip install --quiet
#     print("DONE install ",xthe_url)

# %% [raw]
# update = True
#
# from os import path
# import os
# # if not path.exists("/kaggle/working/ComfyUI/"):
# %cd /kaggle/working
# if not path.exists("/kaggle/working/ComfyUI/"):
#     get_ipython().system(f'git clone https://github.com/comfyanonymous/ComfyUI.git')
# %cd ComfyUI
# if update:
#     get_ipython().system('git pull --all')
# !uv pip install --system  -r requirements.txt --quiet

# %% [raw]
# import os
# if not os.path.exists("/kaggle/working/ComfyUI/models/LLM"):
#     os.makedirs("/kaggle/working/ComfyUI/models/LLM")
# if not os.path.exists("/kaggle/working/ComfyUI/models/pulid"):
#     os.makedirs("/kaggle/working/ComfyUI/models/pulid")
# if not os.path.exists("/kaggle/working/ComfyUI/models/clip_vision"):
#     os.makedirs("/kaggle/working/ComfyUI/models/clip_vision")
# if not os.path.exists("/kaggle/working/ComfyUI/models/xlabs/contronets"):
#     os.makedirs("/kaggle/working/ComfyUI/models/xlabs/contronets/")

# %% [raw]
# %rm -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Easy-Use

# %% [raw]
# install_this("https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4")
# # Was node
# install_this('https://github.com/WASasquatch/was-node-suite-comfyui')
# # Rgthree
# install_this("https://github.com/rgthree/rgthree-comfy")
# # REactor
# install_this("https://codeberg.org/Gourieff/comfyui-reactor-node")
# # Comfyui noise
# install_this("https://github.com/BlenderNeko/ComfyUI_Noise")
# # Comfyui impact
# install_this("https://github.com/ltdrdata/ComfyUI-Impact-Pack")
# # pythongossss
# install_this("https://github.com/pythongosssss/ComfyUI-Custom-Scripts")
# # Comfyui easy use
# install_this("https://github.com/yolain/ComfyUI-Easy-Use")
# # KJNODES
# install_this("https://github.com/kijai/ComfyUI-KJNodes")
# # Flux comfyui
# install_this("https://github.com/kijai/ComfyUI-Florence2")
# install_this("https://github.com/XLabs-AI/x-flux-comfyui")
# install_this("https://github.com/crystian/ComfyUI-Crystools")
# install_this("https://github.com/city96/ComfyUI-GGUF")
#
# install_this("https://github.com/cubiq/PuLID_ComfyUI")
# install_this("https://github.com/cubiq/ComfyUI_InstantID")
# install_this("https://github.com/cubiq/ComfyUI_IPAdapter_plus")
# install_this("https://github.com/revirevy/Comfyui_saveimage_imgbb")
#
# # install_this("https://github.com/ltdrdata/ComfyUI-Manager")

# %% [raw]
# for x in """https://github.com/comfyanonymous/ComfyUI_experiments
# https://github.com/chengzeyi/Comfy-WaveSpeed
#     https://github.com/Fannovel16/comfyui_controlnet_aux
#     https://github.com/ShmuelRonen/ComfyUI-FreeMemory
#         https://github.com/jamesWalker55/comfyui-various
#             https://github.com/kijai/ComfyUI-SUPIR
#                 https://github.com/klinter007/klinter_nodes
#     https://github.com/holchan/ComfyUI-ModelDownloader
#         https://github.com/KoreTeknology/ComfyUI-Universal-Styler
#             https://github.com/marduk191/ComfyUI-Fluxpromptenhancer
#                 https://github.com/fairy-root/Flux-Prompt-Generator
#                     https://github.com/VykosX/ControlFlowUtils
#                         https://github.com/godmt/ComfyUI-List-Utils""".split("\n"):
#     install_this(x.strip())
# print("="*50,'ALL DONE','='*50,sep='\n')

# %% [raw]
# install_this("https://github.com/ltdrdata/ComfyUI-Manager")

# %% [raw]
# !ln -s  /kaggle/input/clip-gmp-vit-l-14/tensorflow2/default/1/model.safetensors    /kaggle/working/ComfyUI/models/clip/CLIP_gmp_VIT_L_14.safetensors
#
# # !ls -trahl  /kaggle/working/ComfyUI/models/vae
#
# # !ls -trahl  /kaggle/working/ComfyUI/models/clip/
# # !ls -ltrah /kaggle/input/
#
# !ln -s /kaggle/input/t5xxl_fp16.safetensors/tensorflow2/default/1/t5xxl_fp16.safetensors   /kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors
# !ln -s  /kaggle/input/flux-vae-safetensors/pytorch/default/1/ae.safetensors    /kaggle/working/ComfyUI/models/vae/FLuX_ae.safetensors
#
# # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/flux1-dev-fp8.safetensors -d /kaggle/working/ComfyUI/models/unet -o flux1-dev-fp8.safetensors
# # !ln -s /kaggle/input/flux/pytorch/flux.1-dev/1/flux1-dev.safetensors /kaggle/working/ComfyUI/models/unet/flux1-dev.safetensors
# # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/ae.sft -d /kaggle/working/ComfyUI/models/vae -o ae.sft
# # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/clip_l.safetensors -d /kaggle/working/ComfyUI/models/clip -o clip_l.safetensors
# # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/t5xxl_fp8_e4m3fn.safetensors -d /kaggle/working/ComfyUI/models/clip -o t5xxl_fp8_e4m3fn.safetensors
# !ln -s /kaggle/input/clip/pytorch/t5xxl_fp8_e4m3fn/1/t5xxl_fp8_e4m3fn.safetensors /kaggle/working/ComfyUI/models/clip/t5xxl_fp8_e4m3fn.safetensors
# # !ln -s  /kaggle/input/t5-fine-tuned/transformers/t5-2/1/model.safetensors    /kaggle/working/ComfyUI/models/clip/t5-2-model.safetensors
# # !ln -s /kaggle/input/t5xxl_fp16/tensorflow2/default/1/t5xxl_fp16.safetensors   /kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors
#
# # !ln -s  /kaggle/input/flan-t5/pytorch/large/3/model.safetensors             /kaggle/working/ComfyUI/models/clip/flan-t5-large-model.safetensors
# # !ln -s  /kaggle/input/clip-gpt2_t5/pytorch/1/1/net-cross-description.pt    /kaggle/working/ComfyUI/models/clip/net-cross-description.pt
#
# !ln -s /kaggle/input/florence2/transformers/default/1/Florence2_model_3/model.safetensors /kaggle/working/ComfyUI/models/LLM/Florence_model_3.safetensors
# !ln -s /kaggle/input/florence2/transformers/default/1/Florence2_model_2/model.safetensors /kaggle/working/ComfyUI/models/LLM/Florence_model_2.safetensors
# !ln -s /kaggle/input/controlnet/pytorch/flux-canny-controlnet/1/flux-canny-controlnet-v3.safetensors  /kaggle/working/ComfyUI/models/xlabs/contronets/flux-canny-controlnet-v3.safetensors
# !ln -s /kaggle/input/controlnet/pytorch/flux-depth-controlnet/1/flux-depth-controlnet-v3.safetensors  /kaggle/working/ComfyUI/models/xlabs/contronets/flux-depth-controlnet-v3.safetensors
# # !ln -s /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_base_1.0_0.9vae.safetensors /kaggle/working/ComfyUI/models/checkpoints/sd_xl_base_1.0_0.9vae.safetensors
#
# !ln -s /kaggle/input/realvisxl-v50/pytorch/default/1/realvisxl-v50.safetensors  /kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50.safetensors
# !ln -s /kaggle/input/realvisxl-v50/pytorch/default/2/SG161222_RealVisXL_V5_0_Lightning.safetensors  /kaggle/working/ComfyUI/models/checkpoints/SG161222_RealVisXL_V5_0_Lightning.safetensors
# # !ln -s /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_base_1.0.safetensors /kaggle/working/ComfyUI/models/checkpoints/sd_xl_base_1.0.safetensors
# # !ln -s /kaggle/input/stoiqo-new-reality-flux-sd_f1d-pre-alpha/transformers/default/1/STOIQONewrealityFLUXSD_F1DPreAlpha.safetensors /kaggle/working/ComfyUI/models/checkpoints/STOIQONewrealityFLUXSD_F1DPreAlpha.safetensors
# !ln -s /kaggle/input/flux1devnf46stepsnsfw/pytorch/default/1/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors /kaggle/working/ComfyUI/models/checkpoints/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors
# !ln -s /kaggle/input/8stepscrearthyperfluxdevbnb_v24hyperdevfp8unet_/pytorch/default/1/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors  /kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors
# !ln -s /kaggle/input/creart-hyper-flux-dev-gguf-q4_0/gguf/default/1/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf /kaggle/working/ComfyUI/models/unet/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf
# !ln -s /kaggle/input/unet/gguf/flux1-dev-q4_k_s/1/flux1-dev-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf
# !ln -s /kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors /kaggle/working/ComfyUI/models/checkpoints/albedobaseXL_v3Mini.safetensors
# # /kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors
#
#
#
# !ln -s /kaggle/input/alimama-flux-turbo-lora/pytorch/default/1/diffusion_pytorch_model.safetensors /kaggle/working/ComfyUI/models/loras/alimama-flux-turbo-lora.safetensors
#
# !ln -s /kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors  /kaggle/working/ComfyUI/models/checkpoints/fluxArtfusion4Steps_v12.safetensors
# # !ln -s /kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors
#
#
# for x in os.listdir("/kaggle/input/flux_loras/pytorch/default/1"):
#     print(x)
#     !ln -s "/kaggle/input/flux_loras/pytorch/default/1/$x" "/kaggle/working/ComfyUI/models/loras/$x"

# %%
# os.makedirs("/kaggle/working/ComfyUI/models/InstantIR/models",)
for x in os.listdir("/kaggle/input/instantir/pytorch/default/2/"):
    print(x)
    # !ln -s "/kaggle/input/instantir/pytorch/default/2/$x" "/kaggle/working/ComfyUI/models/InstantIR/models/$x"

# %% [raw]
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# for x in os.listdir("/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/"):
#     print(x)
#     !ln -s "/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/$x" "/kaggle/working/ComfyUI/models/clip/$x"

# %% [raw]
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# # /kaggle/input/sdxl_controlnets/pytorch/default/2
# os.makedirs('/kaggle/working/ComfyUI/models/ipadapter',exist_ok=True)
# os.makedirs('/kaggle/working/ComfyUI/models/controlnet',exist_ok=True)
# for x in os.listdir("/kaggle/input/sdxl_controlnets/pytorch/default/3/"):
#     # !rm /kaggle/working/ComfyUI/models/controlnet/$x
#     print(x)
#     !ln -s "/kaggle/input/sdxl_controlnets/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/controlnet/$x"
#     if 'ip-adapter' in x:
#         !ln -s "/kaggle/input/sdxl_controlnets/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/ipadapter/$x"

# %% [raw]
# for x in os.listdir("/kaggle/input/pulid-model/pytorch/default/3/"):
#     print(x)
#     !ln -s "/kaggle/input/pulid-model/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/pulid/$x"
#
#
# # /kaggle/input/pulid-model/pytorch/default/3/ip-adapter_pulid_sdxl_fp16.safetensors
# # !ln -s /kaggle/input/pulid-model/pytorch/default/2/pulid_v1.bin /kaggle/working/ComfyUI/models/pulid/pulid_v1.bin
# # !ln -s /kaggle/input/pulid-model/pytorch/default/1/pulid_flux_v0.9.0.safetensors /kaggle/working/ComfyUI/models/pulid/pulid_flux_v0.9.0.safetensors
# !ln -s /kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin  /kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin

# %% [raw]
# os.makedirs('/kaggle/working/ComfyUI/models/controlnet/instantid',exist_ok=True)
# !ln -s /kaggle/input/instant_id/pytorch/default/2/controlnet_instantid_model.safetensors /kaggle/working/ComfyUI/models/controlnet/instantid/LeInstantID_ControlNet_model.safetensors

# %% [raw]
# os.makedirs('/kaggle/working/ComfyUI/models/instantid/SDXL',exist_ok=True)
# !ln -s /kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin /kaggle/working/ComfyUI/models/instantid/InstantID_ip_adapter.bin
# !ln -s /kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin /kaggle/working/ComfyUI/models/instantid/ip_adapter.bin
# !ln -s /kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin /kaggle/working/ComfyUI/models/instantid/SDXL/ip-adapter.bin

# %% [raw]
# for x in os.listdir("/kaggle/input/pulid-model/pytorch/default/3/"):
#     print(x)
#     !ln -s "/kaggle/input/pulid-model/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/pulid/$x"
#
#
# # /kaggle/input/pulid-model/pytorch/default/3/ip-adapter_pulid_sdxl_fp16.safetensors
# # !ln -s /kaggle/input/pulid-model/pytorch/default/2/pulid_v1.bin /kaggle/working/ComfyUI/models/pulid/pulid_v1.bin
# # !ln -s /kaggle/input/pulid-model/pytorch/default/1/pulid_flux_v0.9.0.safetensors /kaggle/working/ComfyUI/models/pulid/pulid_flux_v0.9.0.safetensors
# !ln -s /kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin  /kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin

# %% [raw]
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# # /kaggle/input/sdxl_controlnets/pytorch/default/2
# for x in os.listdir("/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/"):
#     print(x)
#     !ln -s "/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/$x" "/kaggle/working/ComfyUI/models/controlnet/$x"

# %% [raw]
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# #     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# for x in os.listdir("/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/"):
#     print(x)
#     !ln -s "/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/$x" "/kaggle/working/ComfyUI/models/clip/$x"

# %% [raw]
# for x in os.listdir("/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/"):
#     print(x)
#     !ln -s "/kaggle/input/4xnomosunidat_upscaler/pytorch/default/5/$x" "/kaggle/working/ComfyUI/models/upscale_models/$x"

# %% [raw]
# %ls -ltrha /kaggle/working/ComfyUI/models/clip/

# %% [raw]
# %%writefile /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/config.ini
# [default]
# preview_method = none
# badge_mode = none
# git_exe =
# channel_url = https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main
# share_option = all
# bypass_ssl = False
# file_logging = True
# default_ui = none
# component_policy = workflow
# double_click_policy = copy-all
# windows_selector_event_loop_policy = False
# model_download_by_agent = True
# downgrade_blacklist =
# security_level = normal-

# %% [raw]
# # Comfyui impact
# install_this("https://github.com/ltdrdata/ComfyUI-Impact-Pack")

# %% [raw]
# !uv pip install insightface onnxruntime-gpu diffusers einops accelerate -q torch torchvision torchsde --system

# %% [raw]
# # Change directory to ComfyUI
# import os, subprocess, time
# os.chdir("/kaggle/working/ComfyUI/")
#
# # Launch ComfyUI instances
# xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram",])
# time.sleep(10)

# %% [raw]
# os.chdir("/kaggle/working/ComfyUI/")
# xP2= subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189","--highvram"])
# time.sleep(10)
# # subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "0", "--port", "8188"])
# # subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "1", "--port", "8189"])
#
# # time.sleep(30)

# %% [raw]
# os.chdir("/kaggle/working/ComfyUI/")
# if  not os.path.exists('/kaggle/working/ComfyUI/playit-linux-amd64'):
#     !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64
# !chmod 777 /kaggle/working/ComfyUI/playit-linux-amd64
#
# !ls -ltrha play*

# %% [raw]
# # !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64 -q
# !chmod +x ./playit-linux-amd64
# !./playit-linux-amd64  --help

# %% [raw]
# os.makedirs("/kaggle/working/ComfyUI/logs",exist_ok=True)
# subprocess.Popen("nohup /kaggle/working/ComfyUI/playit-linux-amd64   >> /kaggle/working/ComfyUI/logs/playit.log 2>&1 & echo 'done' ",bufsize=0,shell=True)

# %% [raw]
# time.sleep(3)
# !tail -n 20 /kaggle/working/ComfyUI/logs/playit.log

# %% [raw]
# %cp /kaggle/working/ComfyUI/models/insightface/models/antelopev2/antelopev2/* /kaggle/working/ComfyUI/models/insightface/models/antelopev2/ -v

# %% [raw]
# %ls /kaggle/working/ComfyUI/models/insightface/models -ltrha

# %% [raw]
# !ps fx

# %%
import threading
import time,datetime
from IPython.core.getipython import get_ipython

def execute_first_cell():
    print("="*10,"Executed ",datetime.datetime.today(),"="*10)
    get_ipython().run_cell(get_ipython().user_ns['_i1'])
    print("="*60)
def scheduler():
    while True:
        execute_first_cell()
        time.sleep(60)  # 600 seconds = 10 minutes

# Start the scheduler in a separate thread
scheduler_thread = threading.Thread(target=scheduler)
scheduler_thread.daemon = True  # This allows the thread to be terminated when the main program exits
scheduler_thread.start()

print("Scheduler started in background. It will execute the first cell every 1 minutes.")

# %% [raw]
# !python main.py --help

# %%
# !curl http://localhost:8188/api

# %%
get_ipython().user_ns

# %% [raw]
# !ln -s /kaggle/input/realvisxl-v50/pytorch/default/1/realvisxl-v50.safetensors  /kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50
#
# !du --max-depth 1 /kaggle/working/ComfyUI/models/ -lc | sort -k1 -n
#
# !ls -ltrha  /kaggle/working/ComfyUI/models/ipadapter/ #-lc | sort -k1 -n
# # !rm /kaggle/working/ComfyUI/models/ipadapter/ip-adapter-faceid-plusv2_sdxl.bin #/kaggle/working/ComfyUI/models/instantid/SDXL/ip-adapter.bin
#
# !ls -ltrha  /kaggle/working/ComfyUI/models/facerestore_models #-lc | sort -k1 -n
#
# # !rm /kaggle/working/ComfyUI/models/facerestore_models/*
#
# from IPython.display import display, HTML, FileLink
#
# display(HTML("<style>.container { width:100% !important; }</style>"))
# from IPython.display import display, HTML
#
# display(HTML("<style>.output_area pre { white-space: pre-wrap; }</style>"))
# os.chdir("/kaggle/working/")
# display(FileLink('output_18112024_1959.zip.zip'))
# os.chdir("/kaggle/working/ComfyUI/")
#
# !ps fax
#
#  # !mkdir /kaggle/working/ComfyUI/logs
#
# # !rm playit-linux-amd64*
#
# os.chdir("/kaggle/working/ComfyUI/")
# if  not os.path.exists('/kaggle/working/ComfyUI/playit-linux-amd64'):
#     !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64
# !chmod 777 /kaggle/working/ComfyUI/playit-linux-amd64
#
# !ls -ltrha play*
#
# # !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64 -q
# !chmod +x ./playit-linux-amd64
# !./playit-linux-amd64  --help
#
# subprocess.Popen("nohup /kaggle/working/ComfyUI/playit-linux-amd64   >> /kaggle/working/ComfyUI/logs/playit.log 2>&1 & echo 'done' ",bufsize=0,shell=True)
#
# !tail -n 20 /kaggle/working/ComfyUI/logs/playit.log
#
# !ps fax
#
#
#
#
#
# # !rm /kaggle/working/ComfyUI/models/controlnet/*
#
# !ls -trha /kaggle/input/sdxl_controlnets/pytorch/default/2
#
#
# !ls -ltrha /kaggle/working/ComfyUI/models/controlnet
#
# !ls -ltrha /kaggle/working/ComfyUI/models/controlnet/SDXL
#
# !rm /kaggle/working/ComfyUI/models/controlnet/OpenPoseXL2.safetensors
# !rm /kaggle/working/ComfyUI/models/controlnet/depth-zoe-xl-v1.0-controlnet.safetensors
#
#
#
#
#
# !kill 1471
#
#
#
# # !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64 -q
# !chmod +x ./playit-linux-amd64
# !./playit-linux-amd64  --help
#
# subprocess.Popen(["/kaggle/working/ComfyUI/playit-linux-amd64","-l","playit.log"],shell=True)
#
# !ps fax
#
# !df -h
#
# !df -h /kaggle/working
#
# !du --help
#
# !du -h -d1  /kaggle/working/ComfyUI/models | sort -k1
#
# !du -h   /kaggle/working/ComfyUI/models/controlnet | sort -k1
#
# !rm /kaggle/working/ComfyUI/models/controlnet/SDXL/controlnet-tile-sdxl-1.0/ -r
#
#
# !sudo apt install net-tools -q
#
# !netstat -nltp
#
# !kill 1059 1146 1159 1177
#
#
#
#
#
# !./playit-linux-amd64
#
# subprocess.run("/kaggle/working/ComfyUI/playit-linux-amd64 tunnels list &",shell=True)
#
# port=8188
# command = f"cd /kaggle/working/ComfyUI/ ; nohup /kaggle/working/ComfyUI/playit-linux-amd64 start >> nohup{port}.out 2>&1 & echo $!"
# p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
# for line in p.stdout:
#     print(line.decode(), end='')
#
# port=8189
# command = f"nohup ./playit-linux-amd64 >> nohup{port}.out 2>&1 & echo $!"
# p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
# for line in p.stdout:
#     print(line.decode(), end='')
#
# !kill 1405 1415  1417 1419 1403 1425
#
# !ps fax
#
# ## os.chdir("/kaggle/working/ComfyUI/")
# subprocess.run("tail -f nohup8188.out &",shell=True)
#
#
#
#
#
#
#
#
#
#
#
# import subprocess,os
# import threading
# import time
# import socket
# import urllib.request
#
# get_ipython().system("npm install -g npm")
# get_ipython().system("npm install -g localtunnel")
#
# # Change directory to ComfyUI
# os.chdir("/kaggle/working/ComfyUI/")
#
# # Launch ComfyUI instances
# xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
# time.sleep(30)
#
# xP2= subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189","--highvram"])
# time.sleep(30)
# # subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "0", "--port", "8188"])
# # subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "1", "--port", "8189"])
#
# # time.sleep(30)
#
# !kill 2176 2179  2178 2181
#
# !ps fax
#
#
#
# !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64
#
# !chmod +x ./playit-linux-amd64
#
# !./playit-linux-amd64 tunnels list
#
# !./playit-linux-amd64 --help
#
# !ssh -R 80:localhost:8188 localhost.run
#
# !openssl version
#
# !ssh -p 443 -R0:localhost:8000 -L4300:localhost:4300 qr@a.pinggy.io
#
#
#
# !lt --help
#
# def iframe_thread(port):
#   while True:
#       time.sleep(0.5)
#       sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       result = sock.connect_ex(('127.0.0.1', port))
#       if result == 0:
#         break
#       sock.close()
#   print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")
#
#   print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# #   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
#   command = f"nohup lt --port {port} --allow-invalid-cert --print-requests >> nohup{port}.out 2>&1 & echo $!"
#   p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
#   for line in p.stdout:
#     print(line.decode(), end='')
#
#
# # threading.Thread(target=iframe_thread, daemon=True, args=(8188,8189,)).start()
# # %cd /kaggle/working/ComfyUI/
# # # threading.Thread(target=iframe_thread, daemon=True, args=(8189,)).start()
# # !python main.py  --cuda-device 0 --port 8188; python main.py --cuda-device 1 --port 8189
# # # --dont-print-server
#
# # Start threads for both ports
# xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
# xT1.start()
# xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
# xT2.start()
#
# subprocess.run("tail -f nohup8188.out &",shell=True)
#
# subprocess.run("tail -f nohup8189.out &",shell=True)
#
#
#
#
#
#
#
# !curl -O https://install.tunnelmole.com/xD345/install && sudo bash install
#
# port=8188
# command = f"nohup tmole {port} >> nohup{port}.out 2>&1 & echo $!"
# p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
#
# !ps fax
#
# !tail -f nohup8188.out
#
# subprocess.run("tail -f nohup8188.out &",shell=True)
#
# port=8189
# command = f"nohup tmole {port} >> nohup{port}.out 2>&1 & echo $!"
# p2 = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
#
# subprocess.run("tail -f nohup8189.out &",shell=True)
#
#
#
# %ls /kaggle/working/old_output
#
#
#
# def iframe_thread(port):
#   while True:
#       time.sleep(0.5)
#       sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       result = sock.connect_ex(('127.0.0.1', port))
#       if result == 0:
#         break
#       sock.close()
#   print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")
#
#   print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# #   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
#   command = f"nohup lt --port {port} --print-requests >> nohup{port}.out 2>&1 & echo $!"
#   p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
#   for line in p.stdout:
#     print(line.decode(), end='')
#
#
# # threading.Thread(target=iframe_thread, daemon=True, args=(8188,8189,)).start()
# # %cd /kaggle/working/ComfyUI/
# # # threading.Thread(target=iframe_thread, daemon=True, args=(8189,)).start()
# # !python main.py  --cuda-device 0 --port 8188; python main.py --cuda-device 1 --port 8189
# # # --dont-print-server
#
# # Start threads for both ports
# xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
# xT1.start()
# xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
# xT2.start()
#
# <span style="background-color: #add8e6; color: #8b0000; padding: 5px;">
#   <font size=18px>HERE PS.
# </span>
#
# !ps fax
#
# !kill 1220 1331 1343 1353 1368 1169 1206 1074
#
#
#
#
#
#
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
#
# import subprocess
# import threading
# import time
#
#
# xport=  8188
# command = f"nohup cloudflared tunnel --url http://localhost:{xport} >> nohup{xport}.out 2>&1 & echo $!"
# p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
# for line in p.stdout:
#     print(line.decode(), end='')
#
# import subprocess
# subprocess.Popen(["cloudflared", "tunnel", '--url', f'http://localhost:8188',]) #"run", "my-tunnel"])
#
# !ps fax
#
#
#
# import subprocess
# subprocess.Popen(["cloudflared", "tunnel", '--url', f'http://localhost:8189',]) #"run", "my-tunnel"])
#
# !ps fax
#
# !uv pip install --system cloudflared
#
# from cloudflared import CloudFlare
# CloudFlare.subprocess()
#
#
#
#
#
#
#
#
#
# !uv pip install --system -q pyngrok
# !ngrok authtoken "2f3dIfgJffUXDkLfUJ4V0PBrdln_74tALZeMqwobwcbyupmuw"
#
# from pyngrok import ngrok
# public_url = ngrok.connect('localhost:8188')
# print(f"Please click on the text below {public_url}")
#
# from pyngrok import ngrok
# public_url = ngrok.connect('localhost:8189')
# print(f"Please click on the text below {public_url}")
#
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
#
# import subprocess
# import threading
# import time
#
#
# def start_tunnel(xport=8188):
#     tunnel_process = subprocess.Popen(
#         ['cloudflared', 'tunnel', '--url', f'http://localhost:{xport}'],
#         stdout=subprocess.PIPE,
#         stderr=subprocess.STDOUT,
#         universal_newlines=True
#     )
#
#     # Look for the tunnel URL in the output
#     while True:
#         output = tunnel_process.stdout.readline()
#         if output:
#             if 'trycloudflare.com' in output:
#                 # Extract and display the URL
#                 url = output.split('|')[3].strip()
#                 print(f"ComfyUI is available at: {url}")
#                 break
#
# # Start the tunnel in a separate thread
# # tunnel_thread = threading.Thread(target=start_tunnel,args=(8188,), daemon=True)
# # tunnel_thread.start()
#
# xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
# time.sleep(30)
# # Wait a moment for the tunnel to establish
# time.sleep(5)
#
# !ps fax
#
#
#
# !wget https://huggingface.co/guozinan/PuLID/resolve/main/pulid_flux_v0.9.0.safetensors
#
#
#
#
#
# %pip install -U pip uv -q
# # !uv venv
# # !source .venv/bin/activate
# !uv pip install --system  --quiet pyngrok #--system
# !uv pip install --system --no-deps --quiet protobuf==3.20.*   #==4.21.12
# !uv pip install  --system --no-deps --quiet validators
# !ngrok authtoken "2f3dIfgJffUXDkLfUJ4V0PBrdln_74tALZeMqwobwcbyupmuw"
#
# !uv  pip install   --system  -q omegaconf accelerate einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !uv pip install  --system -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 ultralytics insightface bitsandbytes
# !uv pip install  --system -q torchsde
#
# # Change directory to ComfyUI
# os.chdir("/kaggle/working/ComfyUI/")
#
# # Launch ComfyUI instances
# xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
# time.sleep(30)
#
# xP2= subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189","--highvram"])
# time.sleep(30)
# # subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "0", "--port", "8188"])
# # subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "1", "--port", "8189"])
#
# # time.sleep(30)
#
# !ps fax
#
# from pyngrok import ngrok
# # import ngrok
#
# # listener = ngrok.forward("localhost:8080", authtoken_from_env=True)
#
# # print(f"Ingress established at: {listener.url()}");
#
#
# public_url = ngrok.connect('localhost:8188')
# print(f"Please click on the text below {public_url}")
#
# from pyngrok import ngrok
# public_url = ngrok.connect('localhost:8189')
# print(f"Please click on the text below {public_url}")
#
# !ps fax
#
# !ls -ltrah /kaggle/working/ComfyUI/models/clip_vision
#
# !rm /kaggle/working/ComfyUI/models/clip_vision/clip-vit-large-patch14.safetensors
#
# # !sudo apt install ncdu
# !kill 659 701
#
# !du -h /kaggle/working/ComfyUI/models/
#
# !du -h /kaggle/working/ComfyUI/models/clip/t5
#
# !ls -ltrah /kaggle/working/ComfyUI/models/clip/t5
#
#
#
#
#
#
#
# def iframe_thread(port):
#   while True:
#       time.sleep(0.5)
#       sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       result = sock.connect_ex(('127.0.0.1', port))
#       if result == 0:
#         break
#       sock.close()
#   print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")
#
#   print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
#   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
#   command = f"nohup lt --port {port} --print-requests >> nohup{port}.out 2>&1 & echo $!"
#   p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
#   for line in p.stdout:
#     print(line.decode(), end='')
#
#
# # threading.Thread(target=iframe_thread, daemon=True, args=(8188,8189,)).start()
# # %cd /kaggle/working/ComfyUI/
# # # threading.Thread(target=iframe_thread, daemon=True, args=(8189,)).start()
# # !python main.py  --cuda-device 0 --port 8188; python main.py --cuda-device 1 --port 8189
# # # --dont-print-server
#
# %pip install uv
#
# !uv pip --help
#
#
#
# # Start threads for both ports
# xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
# xT1.start()
# xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
# xT2.start()
#
# subprocess.run("tail -f nohup8188.out &",shell=True)
#
# subprocess.run("tail -f nohup8189.out &",shell=True)
#
#
#
# !ps fax
#
# !kill 679  682
#
# !kill 929 930 931
#
# xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
# xT1.start()
#
# import subprocess
# import time
#
# def run_cloudflare_tunnel(hostname, local_url):
#     cmd = f"cloudflared tunnel --url {local_url} {hostname}"
#     process = subprocess.Popen(cmd, shell=True)
#     return process
#
# # Configuration
# hostname = "kaggle.com"
# local_url = "http://localhost:8000"
#
# # Start the tunnel
# tunnel_process = run_cloudflare_tunnel(hostname, local_url)
#
# print(f"Tunnel started. Forwarding {hostname} to {local_url}")
# print("Press Ctrl+C to stop the tunnel.")
#
# try:
#     # Keep the script running
#     while True:
#         time.sleep(1)
# except KeyboardInterrupt:
#     print("Stopping the tunnel...")
#     tunnel_process.terminate()
#     print("Tunnel stopped.")
#
# !ps fax
#
# # Start threads for both ports
# # xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
# # xT1.start()
# threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
# # xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
# # xT2.start()
#
# xP1.kill()
# xP2.kill()
#
# xT1._delete()
#
# xT2=xT2.run()
#
# I solved it with code-server and pyngrok
#
#     Install Code-server
#
# !curl -fsSL https://code-server.dev/install.sh | sh
#
#     Install pyngrok & get the tunnel URL (you can't run background process in kaggle)
#
# !pip install pyngrok
#
#     Input ngrok auth token and get tunnel http 80.
#
# from pyngrok import conf, ngrok
#
# conf.get_default().auth_token = "<YOUR TOKEN>"
#
# http_tunnel = ngrok.connect()
# ssh_tunnel = ngrok.connect(80, "http")
#
#     Get the tunnel URL
#
# from pyngrok import ngrok
#
# # [<NgrokTunnel: "http://<public_sub>.ngrok.io" -> "http://localhost:80">]
# tunnels = ngrok.get_tunnels()
# tunnels
#
#     Get code-server default password
#
# !cat  ~/.config/code-server/config.yaml
#
#     run code-server
#
# !code-server --port 80
#
# Hopefully this workaround will work for a while.
#
# !ps fax
#
# !curl https://loca.lt/mytunnelpassword
#
# !curl https://loca.lt/
#
#  !wget -q -O - https://loca.lt/mytunnelpassword
#
# !kill 4103 4104 4102
#
#
#
# %%writefile /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/config.ini
# [default]
# preview_method = none
# badge_mode = none
# git_exe =
# channel_url = https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main
# share_option = all
# bypass_ssl = False
# file_logging = True
# default_ui = none
# component_policy = workflow
# double_click_policy = copy-all
# windows_selector_event_loop_policy = False
# model_download_by_agent = True
# downgrade_blacklist =
# security_level = normal-
#
#
#
# !du -hd1 /kaggle/working/
#
# !du -hd1 /kaggle/working/ComfyUI | sort -rh
#
# !du -hd1 /kaggle/working/ComfyUI/models | sort -rh
#
# !rm /kaggle/working/ComfyUI/.venv -r
#
#
#
# shutil.make_archive("/kaggle/working/old_output.zip", 'zip', "/kaggle/working/old_output")
#
# !rm /kaggle/working/output_18* -v
#
# !rm /kaggle/working/output_19* -v
#
# !rm /kaggle/working/output_* -v
#
# !rm /kaggle/working/old_output* -v -r

# %% [raw]
# !rm /kaggle/working/ComfyUI -r

# %%
# !du -hd1 /kaggle/working/ComfyUI/models | sort -rh

# %%
# !rm /kaggle/working/ComfyUI/models/flashface -r
